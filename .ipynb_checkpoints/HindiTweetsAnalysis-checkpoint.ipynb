# %%
import tweepy as tw
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import seaborn as sns
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from wordcloud import WordCloud, STOPWORDS
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nitin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nitin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
consumer_key = 'mGsFf8tqL8sLLmkgvVvE3HPjN'
consumer_secret = 'q5QSXYDM8nxkJHv8TeSlXkWY2MfLDMEPWkqa8bSFNB6MNhEnmH'
access_token = '1133675761141862400-Ur7UvngZcvdg5h4WIumm0IS3z31Off'
access_token_secret = 'lEDEJK96jKvXmOjvY63ZnoMabelGTPxrMtID7xJl8ByB5'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# search keyword to fetch tweets
search_word = "agneepath"+" -filter:retweets"
date_since = "2022-06-20"

# %%
# Collecting tweets
tweets = tw.Cursor(api.search_tweets, q=search_word, lang="hi-IN", since=date_since).items(500)

# %%
# for tweet in tweets:
#     print(tweet)

# %%
# making list of required info
twt_list=[[tweet.user.screen_name, tweet.text,tweet.user.followers_count, tweet.created_at] for tweet in tweets]
twt_list
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# [['mohiteyuvraj1',
#   'Agitation against Agneepath Yojana... #GoregaonVidhanSabha \u2066@INCMumbai\u2069 \u2066@INCIndia\u2069 https://t.co/uWkJjHubbi',
#   2026,
#   datetime.datetime(2022, 6, 27, 11, 19, 41, tzinfo=datetime.timezone.utc)],
#  ['Thinkwithniche',
#   'आईटी क्षेत्र के इस दिग्गज का अग्निपथ योजना को समर्थन https://t.co/rAwGmQvd8V \n@TwitterIndia @MetaNewsroom… https://t.co/Sg0OxRgWEI',
#   258,
#   datetime.datetime(2022, 6, 27, 11, 18, 32, tzinfo=datetime.timezone.utc)],
#  ['SANDEEPNAUTIYA8',
#   '#आंदोलनजीवी #राजा_बाबू जी कह रहे हैं कि उन 1 करोड़ लोगों कोई भावनायें नहीं है देश के प्रति वे तो सिर्फ बेरोजगार हो… https://t.co/OXtdYwCGWQ',
#   58,
#   datetime.datetime(2022, 6, 27, 11, 15, 31, tzinfo=datetime.timezone.utc)],
#  ['jantaserishta',
#   'अग्निपथ स्कीम के विरोध में कांग्रेस का प्रदर्शन, अचानक हुआ ये...लोग हैरान https://t.co/dQ05wa8DG4',
#   13828,
#   datetime.datetime(2022, 6, 27, 11, 12, 45, tzinfo=datetime.timezone.utc)],
#  ['PramodBJP4170',
#   'अग्निवीर को लेकर युवाओं में भारी उत्साह \n\nअबतक 57000 से अधिक युवाओं ने भरा आवेदन \n\nयुवाओं ने अफवाहबाजी पर लगाया पू… https://t.co/YkfhFEa5SK',
#   1433,
#   datetime.datetime(2022, 6, 27, 11, 11, 42, tzinfo=datetime.timezone.utc)],
#  ['navjivanindia',
#   "#RahulGandhi ने कहा कि प्रधानमंत्री अपने मित्रों को सरकारी संपत्तियों को 50 साल के लिए ठेके पर देकर 'दौलतवीर' बना र… https://t.co/Cm3YMd8dCy",
#   93057,
#   datetime.datetime(2022, 6, 27, 11, 10, 41, tzinfo=datetime.timezone.utc)],
#  ['RamanYa11598893',
#   'सिर्फ बेटियां ही नहीं बेटे भी घर छोड़ जाते है\nउठकर पानी तक ना पीने वाले\nआज अपने कपड़े खुद धो लेते हैं,वह जो कल तक घ… https://t.co/lLPC0MUIZL',
#   640,
#   datetime.datetime(2022, 6, 27, 11, 10, 21, tzinfo=datetime.timezone.utc)],
#  ['PankajyadavpK9',
#   '@IAS_Shruti Mam Agneepath Yojana हमारे समझ से सही नहीं है इसलिए कि हमारे सैनिकों का जो एक्सपीरियंस रहा करता था वह… https://t.co/rfKHRIRqAF',
#   1,
#   datetime.datetime(2022, 6, 27, 11, 10, 10, tzinfo=datetime.timezone.utc)],
#  ['upnewsjunction',
#   'उत्तराखंड में अग्निपथ भर्ती योजना के खिलाफ कांग्रेसियों ने अपनाया अनूठा तरीका\n\n#Uttrakhand #Congress… https://t.co/g46Vv1Cg9P',
#   414,
#   datetime.datetime(2022, 6, 27, 11, 7, 52, tzinfo=datetime.timezone.utc)],
#  ['sunilch10573099',
#   'युवाओं और सेना के हित में है अग्निपथ: वन्दना पोपली-Best24News https://t.co/kgWqYJ1H5o',
#   152,
#   datetime.datetime(2022, 6, 27, 11, 3, 57, tzinfo=datetime.timezone.utc)],
#  ['jantaserishta',
#   'अग्निपथ स्कीम के विरोध में सत्याग्रह आंदोलन, रायपुर में कांग्रेस नेताओं ने किया सुंदरकांड का पाठ https://t.co/qc1rPmoW0V',
#   13828,
#   datetime.datetime(2022, 6, 27, 11, 2, 25, tzinfo=datetime.timezone.utc)],
#  ['inhnewsindia',
#   'अग्निपथ का विरोध : कांग्रेस ने कहा- युवाओं के साथ धोखा, केंद्र सरकार को सद्बुद्धि देने राजधानी में हुआ सुंदरकांड पा… https://t.co/J3lbzAIBsp',
#   6954,
#   datetime.datetime(2022, 6, 27, 11, 1, 52, tzinfo=datetime.timezone.utc)],
#  ['SuryaPr36012650',
#   '@pappuyadavjapl Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳\n#AgnipathScheme',
#   106,
#   datetime.datetime(2022, 6, 27, 11, 1, 21, tzinfo=datetime.timezone.utc)],
#  ['RajExpressNews',
#   "'अग्निपथ योजना' के खिलाफ इन राज्यों में कांग्रेस नेता और RJD कार्यकर्ताओं का विरोध प्रदर्शन\n\n#Agnipath #Congress… https://t.co/j6Yhny0dg3",
#   1355,
#   datetime.datetime(2022, 6, 27, 11, 0, 3, tzinfo=datetime.timezone.utc)],
#  ['dharniavkb',
#   'अग्निपथ योजना के विरोध में देशभर में कांग्रेस ने किया प्रदर्शन, योजना को बताया युवा हित के खिलाफ https://t.co/CREr3BTpuP via @India Awaaz',
#   144,
#   datetime.datetime(2022, 6, 27, 10, 54, 39, tzinfo=datetime.timezone.utc)],
#  ['DanishSaifi_ji',
#   '@LambaAlka Agneepath Yojana Wapas Lo Wapas Lo Wapas Lo Wapas lo',
#   83,
#   datetime.datetime(2022, 6, 27, 10, 53, 57, tzinfo=datetime.timezone.utc)],
#  ['sunilch10573099',
#   'अगिनपथ योजना: जवानों की शहादत का है ‘मजाक’: राज्यसभा सांसद दीपेन्द्र हुड्डा-\xa0Best24news https://t.co/iTwpmeasX6',
#   152,
#   datetime.datetime(2022, 6, 27, 10, 52, 20, tzinfo=datetime.timezone.utc)],
#  ['tricitytoday',
#   'जालौन : अग्निपथ योजना को लेकर धरने पर बैठे कांग्रेसी \n\nWritten by @Dhirendra____ \nhttps://t.co/eQbxDmwGva',
#   7926,
#   datetime.datetime(2022, 6, 27, 10, 51, 3, tzinfo=datetime.timezone.utc)],
#  ['Live_Hindustan',
#   'अग्निवीर बनने के लिए वायुसेना को मिले 56 हजार से अधिक आवेदन, अग्निपथ के विरोध का हुआ कितना असर? https://t.co/N2xC1K9x1w',
#   616378,
#   datetime.datetime(2022, 6, 27, 10, 50, tzinfo=datetime.timezone.utc)],
#  ['news4nations',
#   'अग्निपथ योजना के विरोध में कांग्रेस का सत्याग्रह : भाषण दे रहे कन्हैया कुमार का युवाओं ने किया विरोध, मुर्दाबाद...… https://t.co/orcOVtitDh',
#   38379,
#   datetime.datetime(2022, 6, 27, 10, 45, 51, tzinfo=datetime.timezone.utc)],
#  ['Lallanpost',
#   'अग्निपथ योजना के खिलाफ NSUI ने हरियाणा के भिन्न-भिन्न जिलों में धरना प्रदर्शन किया । https://t.co/EepdTxwc5m',
#   22268,
#   datetime.datetime(2022, 6, 27, 10, 44, 12, tzinfo=datetime.timezone.utc)],
#  ['kirtisol',
#   'अग्निपथ को लेकर बिहार विधानसभा में हंगामा, कानून मंत्री बोले- यूपी में भाजपा की जीत योजना के समर्थन का\xa0उदाहरण https://t.co/W15Cq41Tua',
#   89,
#   datetime.datetime(2022, 6, 27, 10, 44, 5, tzinfo=datetime.timezone.utc)],
#  ['tcp24News',
#   'Mor Mahapaur Mor Dwaar का आज से आगाज, महापौर एजाज़ ढेबर ने समस्या सुनने की स्पेशल बस तैयार... \n \n@AijazDhebar… https://t.co/M0ywGSWJSi',
#   381,
#   datetime.datetime(2022, 6, 27, 10, 43, 11, tzinfo=datetime.timezone.utc)],
#  ['Vipnews24x7',
#   "'अग्निपथ' के विरोध में छत्तीसगढ़ सरकार \n#Chhattisgarh #cmbhupeshbaghel #congress #agneepath https://t.co/BcQwA1mySw",
#   23,
#   datetime.datetime(2022, 6, 27, 10, 42, 55, tzinfo=datetime.timezone.utc)],
#  ['haribhoomicom',
#   'Agneepath Recruitment Scheme: भारी विरोध के बाद अग्निवीरों में भर्ती का जोश, वायुसेना को मिले 3 दिन में 56,960 आवेद… https://t.co/0lVzwrYBjH',
#   871,
#   datetime.datetime(2022, 6, 27, 10, 42, 33, tzinfo=datetime.timezone.utc)],
#  ['HBNtweets',
#   'अग्निपथ योजना के तहत सैनिकों का भविष्य अनिश्चित, केंद्र सेवानिवृत्ति की आयु बढ़ाकर 65 वर्ष करे: बंगाल की सीएम ममता… https://t.co/Vwd372HX4I',
#   671,
#   datetime.datetime(2022, 6, 27, 10, 41, 11, tzinfo=datetime.timezone.utc)],
#  ['marudharhind24',
#   'रामगढ़ में कांग्रेसियों ने अग्निवीर योजना के विरोध में रैली कर दिया ज्ञापन\nhttps://t.co/jo7yyYKfD5',
#   109,
#   datetime.datetime(2022, 6, 27, 10, 41, 9, tzinfo=datetime.timezone.utc)],
#  ['ZeeBiharNews',
#   '#BiharNews : अग्निपथ स्कीम के खिलाफ मुजफ्फरपुर में JAP का प्रदर्शन \n\n#PatnaNews   #Agneepath  #AgnipathScheme https://t.co/d92LWTWmn2',
#   773437,
#   datetime.datetime(2022, 6, 27, 10, 33, 58, tzinfo=datetime.timezone.utc)],
#  ['ParmodK25328588',
#   '@INCMP Agneepath ke bare mein kya Khyal hai madam ji aapka',
#   0,
#   datetime.datetime(2022, 6, 27, 10, 33, 6, tzinfo=datetime.timezone.utc)],
#  ['punjabkesari',
#   'देश की सुरक्षा के लिए भी घातक है अग्निपथ योजना,  दिल्ली कांग्रेस का सरकार पर हमला\nhttps://t.co/kUqGrL3hHa… https://t.co/scGXnul2UC',
#   214371,
#   datetime.datetime(2022, 6, 27, 10, 32, 59, tzinfo=datetime.timezone.utc)],
#  ['SACHKAHOON',
#   'राजस्थान में कांग्रेस का सभी विधानसभा क्षेत्रों में अग्निपथ योजना के खिलाफ सत्याग्रह https://t.co/PpFYxq2gWr',
#   39146,
#   datetime.datetime(2022, 6, 27, 10, 32, 51, tzinfo=datetime.timezone.utc)],
#  ['HindustanUPBH',
#   'पटना में कांग्रेस के अग्निपथ सत्याग्रह में कन्हैया कुमार के विरोध में देशद्रोही के नारे लगे...\n#AgnipathScheme… https://t.co/FLpLnMoqTw',
#   1680,
#   datetime.datetime(2022, 6, 27, 10, 29, 22, tzinfo=datetime.timezone.utc)],
#  ['KarnalBreaking',
#   'CM सिटी में कांग्रेस का अग्निपथ योजना को लेकर हल्ला बोल , करनाल पहुंचे प्रदेश अध्यक्ष , कांग्रेस\xa0प्रभारी… https://t.co/214ZLX3qGt',
#   4238,
#   datetime.datetime(2022, 6, 27, 10, 25, 24, tzinfo=datetime.timezone.utc)],
#  ['Inkhabar',
#   'अग्निपथ योजना: वायुसेना भर्ती के लिए 3 दिन में आए 56,960 आवेदन\n\n#AgnipathScheme #AgnipathProtests… https://t.co/F7kHubmYFN',
#   30596,
#   datetime.datetime(2022, 6, 27, 10, 23, 26, tzinfo=datetime.timezone.utc)],
#  ['News3611',
#   'अग्निपथ योजना के विरोध में कांग्रेसियों ने बुलंद की आवाज https://t.co/dkC92BX2cx via @news-36',
#   20,
#   datetime.datetime(2022, 6, 27, 10, 23, 12, tzinfo=datetime.timezone.utc)],
#  ['khabarbiharlive',
#   'विपक्षी विधायकों के हंगामे, के बीच लंच के बाद पास हुआ अग्नीपथ विधेयक\nhttps://t.co/iBuNANEwOB',
#   15,
#   datetime.datetime(2022, 6, 27, 10, 22, 59, tzinfo=datetime.timezone.utc)],
#  ['AryanAashish',
#   'बिहार विधानसभा में हंगामा, अग्निपथ योजना वापस लेने की मांग https://t.co/OdIL7Pnzcs',
#   151,
#   datetime.datetime(2022, 6, 27, 10, 22, 30, tzinfo=datetime.timezone.utc)],
#  ['AlamAns49559134',
#   'Agneepath kanoon ke khilaf dharna pradarshan https://t.co/MD71SAXxQD',
#   17,
#   datetime.datetime(2022, 6, 27, 10, 21, 16, tzinfo=datetime.timezone.utc)],
#  ['AlamAns49559134',
#   'Agneepath ke khilaf dharna pradarshan',
#   17,
#   datetime.datetime(2022, 6, 27, 10, 20, 29, tzinfo=datetime.timezone.utc)],
#  ['AlamAns49559134',
#   'Agneepath kanoon ke khilaf ham log dharna pradarshan kiye Alam Ansari https://t.co/Zu4xtUIXfo',
#   17,
#   datetime.datetime(2022, 6, 27, 10, 20, 28, tzinfo=datetime.timezone.utc)],
#  ['HindustanUPBH',
#   'अग्निपथ के खिलाफ कांग्रेस का यूपी के जिलों में सत्याग्रह, पूर्व अध्यक्ष लल्लू ने निकाला मार्च\n#Agneepathscheme \nhttps://t.co/LA7saieXy5',
#   1680,
#   datetime.datetime(2022, 6, 27, 10, 20, 8, tzinfo=datetime.timezone.utc)],
#  ['inhnewsindia',
#   '#AgnipathProtest in #Haryana : अग्निपथ के विरोध में हरियाणा में कांग्रेस का धरना- प्रदर्शन, सड़कों पर उतरे नेता और… https://t.co/sANCpPTiwO',
#   6954,
#   datetime.datetime(2022, 6, 27, 10, 17, 30, tzinfo=datetime.timezone.utc)],
#  ['NationalVani',
#   'ऋषिकेश : कांग्रेसी जुटे गंगा किनारे त्रिवेणी घाट पर, सत्याग्रह कर किया अग्निपथ https://t.co/vNQfP5AXxE',
#   49,
#   datetime.datetime(2022, 6, 27, 10, 13, 16, tzinfo=datetime.timezone.utc)],
#  ['LipuJena16',
#   '@Rajukumarjha10 @MarcosPraveen @Rajukumarjha10 b** Jo desh kliye Aaj aapna itna khoya hai tu usko Aisa bol rahahe..… https://t.co/2m0TDCgboI',
#   8,
#   datetime.datetime(2022, 6, 27, 10, 10, 8, tzinfo=datetime.timezone.utc)],
#  ['ashokgarg01',
#   'आज का अग्नि वीर \n#AgnipathScheme #Agneepath https://t.co/5oW3anoZci',
#   69,
#   datetime.datetime(2022, 6, 27, 10, 6, 46, tzinfo=datetime.timezone.utc)],
#  ['RajasthanTvNews',
#   '*Agneepath Scheme: वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया*',
#   2177,
#   datetime.datetime(2022, 6, 27, 10, 3, 51, tzinfo=datetime.timezone.utc)],
#  ['tcp24News',
#   'Mor Mahapaur Mor Dwaar का आज से आगाज, महापौर एजाज़ ढेबर ने समस्या सुनने की स्पेशल बस तैयार...\n\n@AijazDhebar #Raipur… https://t.co/7pScnww2zu',
#   381,
#   datetime.datetime(2022, 6, 27, 10, 1, 42, tzinfo=datetime.timezone.utc)],
#  ['Uttra_News',
#   'Almora - अग्निपथ(Agneepath) योजना के विरोध में कांग्रेस का सत्याग्रह\n\n https://t.co/Hr8pFVTRJH',
#   1159,
#   datetime.datetime(2022, 6, 27, 9, 59, 19, tzinfo=datetime.timezone.utc)],
#  ['AshokRajAhuja5',
#   'रायपुर उत्तर विधानसभा में सत्याग्रह agneepath योजना के विरोध में https://t.co/fYJisR3kGA',
#   12,
#   datetime.datetime(2022, 6, 27, 9, 57, 46, tzinfo=datetime.timezone.utc)],
#  ['MeerutVani',
#   'कांग्रेसियों का अग्निपथ के खिलाफ कलेक्ट्रेट में सत्याग्रह @INCUttarPradesh @INCMeerut \nhttps://t.co/i0n5bgxhcv via @MeerutVani',
#   251,
#   datetime.datetime(2022, 6, 27, 9, 57, 21, tzinfo=datetime.timezone.utc)],
#  ['ShriNiw56981815',
#   'अग्निवीर बनने के लिए वायुसेना को मिले 56 हजार से अधिक आवेदन, अग्निपथ के विरोध का हुआ कितना असर?… https://t.co/0u6kTXgTvK',
#   837,
#   datetime.datetime(2022, 6, 27, 9, 48, 11, tzinfo=datetime.timezone.utc)],
#  ['asbnewsindia',
#   'अग्निपथ स्कीम को लेकर राबड़ी देवी ने पीएम मोदी से की अलग मांग, कहा- सरकार करे ये काम https://t.co/psy6ZC5V1H #AgnipathScheme',
#   1009,
#   datetime.datetime(2022, 6, 27, 9, 43, 40, tzinfo=datetime.timezone.utc)],
#  ['ManojGohana',
#   'आज गोहाना में देश के युवाओं का भविष्य बर्बाद करने वाली भाजपा सरकार की अग्निपथ योजना के खिलाफ कांग्रेस का सत्याग्रह… https://t.co/AUs8dyHFUs',
#   38,
#   datetime.datetime(2022, 6, 27, 9, 38, 54, tzinfo=datetime.timezone.utc)],
#  ['RajKuma04938456',
#   "सरकार के दबाव में 'अग्निपथ' के खिलाफ खुलकर नहीं बोल रहे सेनाधिकारी : परमवीर चक्र विजेता ऑनररी कैप्टन योगेन्द्र सिंह… https://t.co/woEW1eFkot",
#   0,
#   datetime.datetime(2022, 6, 27, 9, 37, 12, tzinfo=datetime.timezone.utc)],
#  ['jantaserishta',
#   'अग्निपथ भर्ती योजना: भारतीय वायुसेना में भर्ती के लिए युवाओं में क्रेज, आए इतने आवेदन https://t.co/IOnllckpvw',
#   13828,
#   datetime.datetime(2022, 6, 27, 9, 34, 11, tzinfo=datetime.timezone.utc)],
#  ['swatvasamachar',
#   'बिहार की पहली महिला मुख्यमंत्री राबड़ी देवी ने कहा कि अग्निपथ योजना देश के लिए ठीक नहीं है। मैं जानती हूं कि प्रधान… https://t.co/JAx2A7fsm3',
#   303,
#   datetime.datetime(2022, 6, 27, 9, 33, 49, tzinfo=datetime.timezone.utc)],
#  ['uttamprithvi',
#   '@uttamprithvi # RSS ne 75 saal se bina koi tankhwa maange DESH ke seva kiye, Kahi Flood Relief to kahi Bhukamp reli… https://t.co/c0nPVVOjmr',
#   157,
#   datetime.datetime(2022, 6, 27, 9, 32, 17, tzinfo=datetime.timezone.utc)],
#  ['abpbihar',
#   'पटना के एसएसपी मानवजीत सिंह ढिल्लो ने कहा कि सभी थाने अलर्ट मोड में हैं. पहले की तरह कोई हिंसा नहीं होगी.\n\nशशांक कु… https://t.co/YAY6KkjCKX',
#   73471,
#   datetime.datetime(2022, 6, 27, 9, 31, 58, tzinfo=datetime.timezone.utc)],
#  ['ABPNews',
#   'पटना के एसएसपी मानवजीत सिंह ढिल्लो ने कहा कि सभी थाने अलर्ट मोड में हैं. पहले की तरह कोई हिंसा नहीं होगी.\n\nशशांक कु… https://t.co/LzYABLjFr8',
#   12661424,
#   datetime.datetime(2022, 6, 27, 9, 31, 44, tzinfo=datetime.timezone.utc)],
#  ['AMROHATV',
#   'अग्निपथ योजना की अग्निपरीक्षा !\n@INCIndia \n\n#AgnipathScheme #AgnipathRecruitmentScheme #AgnipathProtests #Agnipath… https://t.co/1KziZBbDa1',
#   57,
#   datetime.datetime(2022, 6, 27, 9, 31, 33, tzinfo=datetime.timezone.utc)],
#  ['Mukesh_hingar',
#   'Agnipath Scheme वापस लेने की मांग, सड़क पर कांग्रेस https://t.co/sPyoPkiK3R\n#AgnipathProtests #AgnipathScheme #congress #udaipur',
#   1050,
#   datetime.datetime(2022, 6, 27, 9, 31, 13, tzinfo=datetime.timezone.utc)],
#  ['Sanjay97021139',
#   '@ANI Rabri Devi... Agneepath Agneepath Agneepath 😂😂😂😂',
#   13,
#   datetime.datetime(2022, 6, 27, 9, 28, 45, tzinfo=datetime.timezone.utc)],
#  ['DailyNavajyoti',
#   'अग्निपथ योजना का विरोध जारी: कांग्रेस ने 200 विधानसभा क्षेत्रों में किया विरोध प्रदर्शन\nhttps://t.co/JFRpJgwIQ4… https://t.co/du2N9Jl59v',
#   2390,
#   datetime.datetime(2022, 6, 27, 9, 28, 44, tzinfo=datetime.timezone.utc)],
#  ['AmritVichar',
#   'मुरादाबाद : ‘युवाओं के भविष्य से खिलवाड़ बंद करो’, अग्निपथ योजना के खिलाफ कांग्रेसियों का सत्याग्रह\n#Moradabad… https://t.co/FLiXqqi3lS',
#   890,
#   datetime.datetime(2022, 6, 27, 9, 23, 48, tzinfo=datetime.timezone.utc)],
#  ['tcp24News',
#   'Raipur Breaking : अग्निपथ योजना के खिलाफ विरोध प्रदर्शन, पहले किसान आन्दोलन में गई सैंकड़ों किसानों की जान अब अग्नि… https://t.co/8LoTZjkzQF',
#   381,
#   datetime.datetime(2022, 6, 27, 9, 22, 13, tzinfo=datetime.timezone.utc)],
#  ['ZeeBiharNews',
#   'Bihar politics: अग्निपथ स्कीम को लेकर राबड़ी देवी ने उठाई ये बड़ी मांग, कहा-केंद्र करें जल्द से जल्द पूरा… https://t.co/CcQruC5JfC',
#   773437,
#   datetime.datetime(2022, 6, 27, 9, 21, 27, tzinfo=datetime.timezone.utc)],
#  ['AmritVichar',
#   'अमरोहा: ‘अग्निपथ योजना वापस लो’, कांग्रेसियों ने सरकार के खिलाफ किया प्रदर्शन \n@AmritVichar @amrohapolice @dmamroha… https://t.co/wpaCzPQAEe',
#   890,
#   datetime.datetime(2022, 6, 27, 9, 15, 52, tzinfo=datetime.timezone.utc)],
#  ['news_haat',
#   'अग्निपथ योजना को लेकर सत्याग्रह कर रहे कन्हैया कुमार को करना पड़ा विरोध का सामना, युवाओं ने जमकर की नारेबाजी....… https://t.co/v6xoJkGfAu',
#   241,
#   datetime.datetime(2022, 6, 27, 9, 13, 36, tzinfo=datetime.timezone.utc)],
#  ['mateenshareef12',
#   'Agneepath Wapas Lo Wapas Lo \nJai jawan Jai Kisan https://t.co/mUvBaT4pT6',
#   183,
#   datetime.datetime(2022, 6, 27, 9, 9, 5, tzinfo=datetime.timezone.utc)],
#  ['RAJESHK73027173',
#   'Agneepath Nehru Yuva Kendra dwara jagrukta abhiyan https://t.co/n7YV1U7fgi',
#   0,
#   datetime.datetime(2022, 6, 27, 9, 8, 8, tzinfo=datetime.timezone.utc)],
#  ['IND24AMPL',
#   'अग्निपथ योजना पर सियासत, कांग्रेस ने केंद्र सरकार पर किया हमलावर https://t.co/zAvA3DiTTb \n#Agneepathplan #Politics… https://t.co/20nQ21Vd07',
#   12457,
#   datetime.datetime(2022, 6, 27, 9, 8, tzinfo=datetime.timezone.utc)],
#  ['national_views',
#   'अग्निपथ के नाम पर मोदी सरकार देश के युवा पीढ़ी का भविष्य बर्बाद करने पर तुले हुए हैं :जनक ध्रुव प्रदेश अध्यक्ष आदि… https://t.co/uikratG48L',
#   6,
#   datetime.datetime(2022, 6, 27, 9, 3, 40, tzinfo=datetime.timezone.utc)],
#  ['sarika_bjp',
#   '🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳\nसेना की वर्दी *4 दिन मिले या *4 साल गर्व की बात है\n🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳\n@BharatKeAgniveer\n@agniveer\n@Agneepath… https://t.co/cdjjOuk408',
#   112,
#   datetime.datetime(2022, 6, 27, 8, 57, 30, tzinfo=datetime.timezone.utc)],
#  ['samvaad365',
#   'पूर्व सांसद मानवेंद्र सिंह ने केंद्र सरकार पर अग्निपथ योजना को लेकर सरकार पर साधा निशाना\nhttps://t.co/8x3YhiMYsP… https://t.co/shYm2e5V40',
#   182,
#   datetime.datetime(2022, 6, 27, 8, 55, 57, tzinfo=datetime.timezone.utc)],
#  ['News24_MPCG',
#   '"इस देश के युवा और भविष्य के साथ खिलवाड़ करने का काम BJP कर रही है\': @_vikasupadhyay \n\n#Agneepath #AgnipathProtests… https://t.co/M9S2Q4evu9',
#   6724,
#   datetime.datetime(2022, 6, 27, 8, 55, 6, tzinfo=datetime.timezone.utc)],
#  ['PresidentSKP',
#   'Bypolls Results 2022: अग्निपथ विवाद का चुनावों पर नही पड़ा कोई असर, लोकसभा में भाजपा के सांसदों की संख्या हुई\xa0303 https://t.co/woMip7eJ7w',
#   134,
#   datetime.datetime(2022, 6, 27, 8, 52, 4, tzinfo=datetime.timezone.utc)],
#  ['rightnewshp',
#   'Bypolls Results 2022: अग्निपथ विवाद का चुनावों पर नही पड़ा कोई असर, लोकसभा में भाजपा के सांसदों की संख्या हुई\xa0303 https://t.co/dRjAThulC1',
#   81,
#   datetime.datetime(2022, 6, 27, 8, 52, 1, tzinfo=datetime.timezone.utc)],
#  ['Live_Cities',
#   'विधानसभा में पीएम मोदी के खिलाफ विपक्ष की नारेबाजी, BJP भड़की तो सदन 2 बजे तक स्थगित\nhttps://t.co/ds9ToRAAAt',
#   120393,
#   datetime.datetime(2022, 6, 27, 8, 51, 31, tzinfo=datetime.timezone.utc)],
#  ['Dilkush18387482',
#   'इधर हिंदुओं के बच्चों को अग्निपथ योजना के विरुद्ध में खड़ा किया जा रहा है और उधर मौलाना मुस्लिम लड़कों को अग्निपथ… https://t.co/iBmVNxXZ3Y',
#   27,
#   datetime.datetime(2022, 6, 27, 8, 51, 2, tzinfo=datetime.timezone.utc)],
#  ['Live_Cities',
#   '‘अग्निपथ योजना’ को लेकर बहुत गुस्से में राबड़ी देवी, सरकार पर बोला हमला, कहा-जीभ काट लेंगे क्या?\nhttps://t.co/FS4r8Ov1LH',
#   120393,
#   datetime.datetime(2022, 6, 27, 8, 51, tzinfo=datetime.timezone.utc)],
#  ['aryachetananews',
#   'अग्निपथ के विरोध में अमरोहा कलक्ट्रेट पर गरजे\xa0किसान https://t.co/JGVeY6tci5',
#   78,
#   datetime.datetime(2022, 6, 27, 8, 46, tzinfo=datetime.timezone.utc)],
#  ['HCChoudhary',
#   'अग्निपथ योजना: IAF की भर्ती के लिए 3 दिन में 56,960 आवेदन, जानिए रजिस्ट्रेशन की लास्ट डेट  https://t.co/VugzxZ3Vq8 https://t.co/EHtt1aIZr3',
#   185,
#   datetime.datetime(2022, 6, 27, 8, 45, 57, tzinfo=datetime.timezone.utc)],
#  ['mohdimrankhan34',
#   '#PMModi ji kuchh #Agneepathscheme ko wapas le lo ap ki is Agneepath scheme ki vajah se desh ka naujawan depression… https://t.co/PT4DO09Puc',
#   5,
#   datetime.datetime(2022, 6, 27, 8, 41, 38, tzinfo=datetime.timezone.utc)],
#  ['fourthscreenedu',
#   'अग्निपथ योजना: IAF की भर्ती के लिए 3 दिन में 56,960 आवेदन, जानिए रजिस्ट्रेशन की लास्ट डेट \n\nAgneepath Scheme : कें… https://t.co/8cuS7kvzOk',
#   486,
#   datetime.datetime(2022, 6, 27, 8, 40, 36, tzinfo=datetime.timezone.utc)],
#  ['The_FollowUp',
#   'BIHAR : अग्निपथ योजना के विरोध में कांग्रेस करेगी आज सत्याग्रह, कन्हैया कुमार भी पहुंचे पटना\n@INCBihar… https://t.co/wQBQoKzW0i',
#   5131,
#   datetime.datetime(2022, 6, 27, 8, 34, tzinfo=datetime.timezone.utc)],
#  ['Manoj_YSahjanwa',
#   '@kcvenugopalmp @INCIndia 🇮🇳 Agneepath wapas lo\nAadarniy Rahul Gandhi ji jindabad',
#   623,
#   datetime.datetime(2022, 6, 27, 8, 29, 55, tzinfo=datetime.timezone.utc)],
#  ['lagatarIN',
#   'अग्निपथ योजना के विरोध में झारखंड कांग्रेस का सत्याग्रह, डीसी को सौंपा ज्ञापन https://t.co/nnXSbQMRHq… https://t.co/ynE3Ofvbir',
#   909,
#   datetime.datetime(2022, 6, 27, 8, 28, 50, tzinfo=datetime.timezone.utc)],
#  ['swatvasamachar',
#   'अग्निपथ को लेकर विस में हंगामा, भोजन अवकाश के बाद शुरु होगा\xa0सदन https://t.co/qVRMVrAdi3',
#   303,
#   datetime.datetime(2022, 6, 27, 8, 22, 56, tzinfo=datetime.timezone.utc)],
#  ['HemlataTh',
#   'Agneepath scheme : विरोध में उत्तराखंड में कांग्रेस का सत्याग्रह https://t.co/SDyv8wiN32 via @DigitalUp24… https://t.co/Iglg9qMbZw',
#   19,
#   datetime.datetime(2022, 6, 27, 8, 12, 4, tzinfo=datetime.timezone.utc)],
#  ['News18CG',
#   'छत्तीसगढ़ में अग्निपथ योजना के विरोध में कांग्रेस का सत्याग्रह #BreakingNews #Breaking #Congress #Satyagrah… https://t.co/LX2hiHw7F1',
#   20846,
#   datetime.datetime(2022, 6, 27, 8, 10, tzinfo=datetime.timezone.utc)],
#  ['himachal_abhi',
#   'अग्निपथ भर्ती योजना के खिलाफ आज हिमाचल कांग्रेस का सत्याग्रह, सभी ब्लॉक में प्रदर्शन @DrRajeshHPCC @ShuklaRajiv… https://t.co/W5xfk6ULZr',
#   8331,
#   datetime.datetime(2022, 6, 27, 8, 9, 15, tzinfo=datetime.timezone.utc)],
#  ['FederalBharat',
#   'Agnipath Scheme : नोएडा में अग्निपथ योजना का कांग्रेस कार्यकर्ताओं ने कुछ इस तरह किया विरोध \n@INCbudhnagar \n\nhttps://t.co/al8Ud5jQZd',
#   97,
#   datetime.datetime(2022, 6, 27, 8, 9, tzinfo=datetime.timezone.utc)],
#  ['ETVBharatBR',
#   "विधान परिषद में भी 'अग्निपथ' का विरोध, बोलीं राबड़ी- 'देश को आग में झोंकना चाहती है BJP सरकार' @RJDforIndia… https://t.co/TntBwtVI3h",
#   79535,
#   datetime.datetime(2022, 6, 27, 8, 6, 18, tzinfo=datetime.timezone.utc)],
#  ['ehapurnews',
#   'VIDEO: अग्निपथ के विरोध में कांग्रेस का प्रदर्शन https://t.co/Q53zGxfm1p via @ehapurnews #EHapurNews',
#   1154,
#   datetime.datetime(2022, 6, 27, 8, 5, 31, tzinfo=datetime.timezone.utc)],
#  ['patrakar_mojo',
#   'अग्निपथ योजना: “केंद्रीय वी.के.सिंह”\xa0का बड़ा बयान कहा यह कोई दुकान या कंपनी नहीं यह एक स्वैच्छिक योजना है… https://t.co/YnxtplcU08',
#   9,
#   datetime.datetime(2022, 6, 27, 8, 2, 51, tzinfo=datetime.timezone.utc)],
#  ['kuldeepdun',
#   'अग्निपथ योजना ना देश हित में है और ना ही सेना के हित में इससे किसी का भला होने का वाला नहीं है इसलिए मोदी सरकार इस… https://t.co/e7TcyL1SOq',
#   17707,
#   datetime.datetime(2022, 6, 27, 7, 59, 36, tzinfo=datetime.timezone.utc)],
#  ['jantaserishta',
#   'सत्याग्रह आंदोलन: अग्निपथ योजना के विरोध में मंत्री शिवकुमार डहरिया ने किया प्रदर्शन https://t.co/xDhhj732uU',
#   13828,
#   datetime.datetime(2022, 6, 27, 7, 57, 6, tzinfo=datetime.timezone.utc)],
#  ['sharp_bharat',
#   'jamshedpur-rural-केंद्र सरकार की अग्निपथ योजना के विरोध में बहरागोड़ा के कांग्रेसियों ने किया\xa0सत्याग्रह https://t.co/Nk0ocB38IR',
#   934,
#   datetime.datetime(2022, 6, 27, 7, 56, 45, tzinfo=datetime.timezone.utc)],
#  ['AJandhara',
#   'मध्यप्रदेश-छत्तीसगढ़ के नंबर 1न्यूज़ पोर्टल जनधारा 24 के व्हाट्सएप   ग्रुप से जुड़ने के लिए क्लिक करें… https://t.co/Wb5FJoXjSL',
#   834,
#   datetime.datetime(2022, 6, 27, 7, 52, 21, tzinfo=datetime.timezone.utc)],
#  ['WeUttarPradesh',
#   '#लखनऊ :- अग्निपथ योजना के विरोध में कांग्रेस का आज देशव्यापी प्रदर्शन \n#AgnipathScheme #AgnipathRecruitmentScheme… https://t.co/6VAQUSC0Py',
#   142347,
#   datetime.datetime(2022, 6, 27, 7, 52, 3, tzinfo=datetime.timezone.utc)],
#  ['samachartodaytv',
#   'गाजियाबाद में अग्निपथ योजना के विरोध में कांग्रेस का सत्याग्रह, बीजेपी पर लगाएं गंभीर आरोप #देश #प्रदेश #प्रशासनिक… https://t.co/jyS0ySOyq6',
#   2297,
#   datetime.datetime(2022, 6, 27, 7, 43, 4, tzinfo=datetime.timezone.utc)],
#  ['findingsfacts',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n\n#AgnipathScheme',
#   5336,
#   datetime.datetime(2022, 6, 27, 7, 40, 18, tzinfo=datetime.timezone.utc)],
#  ['Dr_VisheshSingh',
#   'हो सकता है अग्निवीर जब भर्ती हों तो हमारे देश की सुरक्षा में कुछ योगदान दें, पर जो परमवीर देश की सुरक्षा के लिए स… https://t.co/Bh6KQXBfie',
#   12797,
#   datetime.datetime(2022, 6, 27, 7, 39, 24, tzinfo=datetime.timezone.utc)],
#  ['Udaybhau69',
#   '@ANI Ahahahhahahah chara Chor ko agneepath Ka virodh Karna hai',
#   525,
#   datetime.datetime(2022, 6, 27, 7, 39, 17, tzinfo=datetime.timezone.utc)],
#  ['ApexNewsIndia',
#   'सम्भल  में अग्नीपथ योजना के खिलाफ कांग्रेस ने किया सत्याग्रह - https://t.co/xap0om1oHZ https://t.co/piHogpdmnT',
#   40,
#   datetime.datetime(2022, 6, 27, 7, 38, 25, tzinfo=datetime.timezone.utc)],
#  ['samachartodaytv',
#   'मुजफ्फरनगर में अग्निपथ योजना का कांग्रेस कार्यकर्ताओं ने कुछ इस तरह किया विरोध #उत्तर प्रदेश #प्रदेश #विविध\nhttps://t.co/KHuaVwbGzc',
#   2297,
#   datetime.datetime(2022, 6, 27, 7, 26, 50, tzinfo=datetime.timezone.utc)],
#  ['ETVBharatBR',
#   "'अग्निपथ' के खिलाफ विधानसभा में RJD का प्रदर्शन, योजना वापस लेने की मांग @RJDforIndia  https://t.co/anGVcm9w8o",
#   79535,
#   datetime.datetime(2022, 6, 27, 7, 19, 27, tzinfo=datetime.timezone.utc)],
#  ['ETVBharatBR',
#   'Bihar Monsoon Session 2022: अग्निपथ योजना के खिलाफ सदन के बाहर कांग्रेस का प्रदर्शन @INCBihar  https://t.co/4J7bI09AIe',
#   79535,
#   datetime.datetime(2022, 6, 27, 7, 18, 33, tzinfo=datetime.timezone.utc)],
#  ['NykAzamgarh',
#   'अग्निपथ योजना\nभारतीय सेना में सेवा देने का एक सुनहरा अवसर।\n#agnipathyojna #Agneepath \n#Agniveer #AgniveerScheme… https://t.co/6mR6xz7AMC',
#   343,
#   datetime.datetime(2022, 6, 27, 7, 14, 19, tzinfo=datetime.timezone.utc)],
#  ['uniquesamaynews',
#   'अग्निपथ योजना: तीन दिन में वायुसेना को मिलेग 56960 आवेदन, पांच जुलाई तक होगा रजिस्ट्रेशन\nhttps://t.co/mewZPWW3to https://t.co/jSuHvQL7X2',
#   205,
#   datetime.datetime(2022, 6, 27, 7, 12, 56, tzinfo=datetime.timezone.utc)],
#  ['IndraMa60201457',
#   '@ashokgehlot51 Are Narendra Modi ka Sapna hai Jo Agneepath har ek Ghar Ghar bacche ko Milana chahie vah pura hoga',
#   0,
#   datetime.datetime(2022, 6, 27, 7, 9, 6, tzinfo=datetime.timezone.utc)],
#  ['upnewsjunction',
#   'अग्निपथ योजना के खिलाफ कांग्रेस का प्रदर्शन, सुबह 10 से दोपहर 1 बजे तक धरना\n\n#AgnipathRecruitmentScheme #Congress\n\nhttps://t.co/gdX3YT8a7c',
#   414,
#   datetime.datetime(2022, 6, 27, 7, 7, 4, tzinfo=datetime.timezone.utc)],
#  ['publicnewstv_in',
#   'अग्निपथ योजना के विरोध में देश भर में कांग्रेस का प्रदर्शन,  सुबह 10 से दोपहर 1 बजे तक करेंगे धरना… https://t.co/jKkfmqleyI',
#   86,
#   datetime.datetime(2022, 6, 27, 7, 3, 17, tzinfo=datetime.timezone.utc)],
#  ['uncensoredlive',
#   'अग्निपथ योजना: भारतीय वायु सेना के लिए पंजीकरण शुरू\nhttps://t.co/vuULjCAm0k\n#Agneepathscheme #IndianArmy… https://t.co/Q392rn0dQ9',
#   266,
#   datetime.datetime(2022, 6, 27, 7, 0, 31, tzinfo=datetime.timezone.utc)],
#  ['ShiftindiaC',
#   'बिहार विधानसभा में अग्निपथ योजना को वापस लेने की मांग पर अड़ा विपक्ष, हंगामा\xa0शुरू https://t.co/ODI03YJU7F',
#   1049,
#   datetime.datetime(2022, 6, 27, 6, 59, 31, tzinfo=datetime.timezone.utc)],
#  ['kirtisol',
#   '‘शादी को भी तरसेंगे अग्निवीर, अग्निपथ योजना युवाओं को कर देगी बर्बाद’, बोले राज्यपाल सत्यपाल\xa0मलिक https://t.co/axLABTMruI',
#   89,
#   datetime.datetime(2022, 6, 27, 6, 54, 6, tzinfo=datetime.timezone.utc)],
#  ['lagatarIN',
#   'अग्निपथ योजना ने रफ्तार पकड़ी, भारतीय वायुसेना में भर्ती के लिए तीन दिन में हुए 56,960 रजिस्ट्रेशन… https://t.co/1lxqeCq1JA',
#   909,
#   datetime.datetime(2022, 6, 27, 6, 50, 14, tzinfo=datetime.timezone.utc)],
#  ['enavabharat',
#   'IAF अग्निपथ भर्ती: योजना के 3000 पदों के लिए 3 दिन में मिले 56960 आवेदन, इस तारीख को पंजीकरण होंगे बंद\n👉… https://t.co/jcd5PJv1aJ',
#   8403,
#   datetime.datetime(2022, 6, 27, 6, 44, 2, tzinfo=datetime.timezone.utc)],
#  ['focus_bharat',
#   'वरुण गांधी ने अग्निवीरों के लिए सांसदों से फिर की पेंशन छोड़ने की अपील https://t.co/21gGeqKuzm \n@varungandhi80',
#   260,
#   datetime.datetime(2022, 6, 27, 6, 41, 40, tzinfo=datetime.timezone.utc)],
#  ['PatrikaNews',
#   'अग्निपथ योजना: IAF की भर्ती के लिए 3 दिन में 56,960 आवेदन, जानिए रजिस्ट्रेशन की लास्ट डेट\n\n#AgneepathScheme… https://t.co/cEf8XPlvXc',
#   218437,
#   datetime.datetime(2022, 6, 27, 6, 40, 59, tzinfo=datetime.timezone.utc)],
#  ['Narendr26388381',
#   'केंद्र सरकार की अग्निपथ योजना का मुस्लिम समाज ने खुलकर किया स्वागत, सुन्नी उलेमा काउंसिल ने युवाओं से की अपील… https://t.co/NhNCDEQVjF',
#   85,
#   datetime.datetime(2022, 6, 27, 6, 37, 1, tzinfo=datetime.timezone.utc)],
#  ['inhnewsindia',
#   'अग्निपथ : कांग्रेस का देशव्यापी प्रदर्शन आज, राजधानी में कांग्रेसी केंद्र सरकार को सद्बुद्धि देने करेंगे सुंदरकांड… https://t.co/RPT5Jlnjyx',
#   6954,
#   datetime.datetime(2022, 6, 27, 6, 36, 22, tzinfo=datetime.timezone.utc)],
#  ['news4nations',
#   'अग्निपथ योजना को लेकर विस में भारी हंगामा, डिप्टी CM बोले- PM पर टिप्पणी उचित नहीं, 2 बजे दिन तक सदन स्थगित...… https://t.co/eKQFtDPkvQ',
#   38379,
#   datetime.datetime(2022, 6, 27, 6, 35, 28, tzinfo=datetime.timezone.utc)],
#  ['jeet_rajan',
#   '@thewirehindi Agneepath Israel ke jaisa military training hai naukari nahi',
#   1869,
#   datetime.datetime(2022, 6, 27, 6, 35, 7, tzinfo=datetime.timezone.utc)],
#  ['news4nations',
#   'अग्निपथ योजना के विरोध में विधानसभा में लगे मोदी विरोधी नारे, कांग्रेस ने कहा - वर्तमान समय में अघोषित इमरजेंसी… https://t.co/C3q0XUXdpp',
#   38379,
#   datetime.datetime(2022, 6, 27, 6, 32, 35, tzinfo=datetime.timezone.utc)],
#  ['SHIVJAAT6',
#   '@toolkitraga Jiske bap ka kam settel h jise dukan ke galle pe baithna h ya jisne kabhi fouji ban na socha he nahi v… https://t.co/6X5LYgTnm1',
#   96,
#   datetime.datetime(2022, 6, 27, 6, 31, 25, tzinfo=datetime.timezone.utc)],
#  ['news4nations',
#   'बिहार विधानसभा में जमकर हंगामा-नारेबाजी, अग्निपथ योजना वापस लेने की मांग...\nhttps://t.co/GGdcPSjlcb\n\n@RJDforIndia… https://t.co/CNhQ8lfMFp',
#   38379,
#   datetime.datetime(2022, 6, 27, 6, 29, 34, tzinfo=datetime.timezone.utc)],
#  ['outlookhindi',
#   'अग्निपथ के ऐलान के बाद युवा नाराजगी आखिर क्यों भड़की \n\n#AgnipathScheme\n@BJP4India @INCIndia @NitishKumar… https://t.co/KBpbLZtd2T',
#   5759,
#   datetime.datetime(2022, 6, 27, 6, 26, 46, tzinfo=datetime.timezone.utc)],
#  ['punjabkesari',
#   'ग्रामीण भारत की महिलाओं के लिए गेम चेंजर साबित हो सकती है अग्निपथ योजना https://t.co/3oB9w6NQZD\n#nationalnews… https://t.co/CzjvPlB360',
#   214371,
#   datetime.datetime(2022, 6, 27, 6, 26, 21, tzinfo=datetime.timezone.utc)],
#  ['madhu___077',
#   'Agneepath Scheme :-\n\nवायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया 👍🏻❤️\n\n      🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳\n#AgnipathScheme  \n\nहर हर महादेव 🙏🏻🚩🔱',
#   1432,
#   datetime.datetime(2022, 6, 27, 6, 25, 2, tzinfo=datetime.timezone.utc)],
#  ['kkumar237997',
#   '@FcSonuSood  hello Sar namaskar Sar Agneepath Yojana ke liye aap sab madad kijiye ise hatane ka koshish Kijiye yah… https://t.co/HbxkVHx02G',
#   6,
#   datetime.datetime(2022, 6, 27, 6, 17, 53, tzinfo=datetime.timezone.utc)],
#  ['mandeepa12',
#   'Agneepath Yojana ke Khilaaf Andolan tohana https://t.co/o10YQL9ULu',
#   3,
#   datetime.datetime(2022, 6, 27, 6, 13, 50, tzinfo=datetime.timezone.utc)],
#  ['thehdnewsindia',
#   '*देश की सुरक्षा को ठेके पर न दे सरकार, अग्निपथ योजना को लेकर भड़के कन्हैया कुमार* https://t.co/E0NkY7myVs… https://t.co/76ytI0G4qZ',
#   242,
#   datetime.datetime(2022, 6, 27, 6, 11, 40, tzinfo=datetime.timezone.utc)],
#  ['HindustanUPBH',
#   'बिहार विधानसभा में हंगामा, अग्निपथ योजना वापस लेने की मांग...\n#AgnipathScheme #Bihar @Live_Hindustan \n\nhttps://t.co/cVFrfyZfKT',
#   1680,
#   datetime.datetime(2022, 6, 27, 6, 4, 54, tzinfo=datetime.timezone.utc)],
#  ['_kaavya_29_',
#   'Agneepath Scheme\n\nRJ/JWA/21/20560040\nKaavya Chandrawanshi\nBanasthali Vidhyapith \n\n@dte_ncc\n@NBanasthali\n@HQ_DG_NCC https://t.co/S3S7piLkJe',
#   15,
#   datetime.datetime(2022, 6, 27, 6, 3, 44, tzinfo=datetime.timezone.utc)],
#  ['123vivekanand',
#   'अग्निपथ योजना को लेकर विस में भारी हंगामा, डिप्टी CM बोले- PM पर टिप्पणी उचित नहीं, 2 बजे दिन तक सदन स्थगित… https://t.co/2nvxlbBXZw',
#   3571,
#   datetime.datetime(2022, 6, 27, 6, 2, 54, tzinfo=datetime.timezone.utc)],
#  ['BiharPatrika',
#   'New post (बिहार के 40 सांसदों को युवाओं की फिक्र नहीं, अग्निपथ पर बोले तेजस्वी) has been published on BIHAR PATRIKA… https://t.co/1I66iRXOYY',
#   435,
#   datetime.datetime(2022, 6, 27, 5, 58, 47, tzinfo=datetime.timezone.utc)],
#  ['NbtRajasthan',
#   'अग्निपथ स्कीम को लेकर आज गर्म रहेगी राजस्थान की राजनीति, RLP और कांग्रेस विरोध के लिए सड़कों पर उतरेगी… https://t.co/R3JYVqGtMR',
#   1139,
#   datetime.datetime(2022, 6, 27, 5, 57, 32, tzinfo=datetime.timezone.utc)],
#  ['Aamodyadav85',
#   'रुझान आना शुरू\n#Agniveer  #Agneepath https://t.co/zB6gE4dM9j',
#   127,
#   datetime.datetime(2022, 6, 27, 5, 51, 15, tzinfo=datetime.timezone.utc)],
#  ['HI_headlines',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया ।\n#agnipathschemeprotests… https://t.co/WX4QXUdzHv',
#   730,
#   datetime.datetime(2022, 6, 27, 5, 47, 39, tzinfo=datetime.timezone.utc)],
#  ['DanishSaifi_ji',
#   '@Pawankhera Agneepath Yojana Wapas Lo Wapas Lo Wapas',
#   83,
#   datetime.datetime(2022, 6, 27, 5, 43, 42, tzinfo=datetime.timezone.utc)],
#  ['AIBSNews24',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n\n#AgnipathScheme https://t.co/ualaTMWSSV',
#   50,
#   datetime.datetime(2022, 6, 27, 5, 41, 28, tzinfo=datetime.timezone.utc)],
#  ['ChaturanandRoy',
#   '@VipinINC @Pawankhera Agneepath scheme  Sena ko barbad kar dega BJP walon Ko Sena aur security ke bare mein kuchh bhi pata nahi h',
#   83,
#   datetime.datetime(2022, 6, 27, 5, 38, 45, tzinfo=datetime.timezone.utc)],
#  ['AnupamRajiv1',
#   'Agneepath Scheme : अग्निपथ पर सीएम भूपेश बघेल बोले- सेना और नौजवानों के साथ खिलवाड़\n#patrika #agnipath #satyagrah… https://t.co/Qjrk77A5iP',
#   72,
#   datetime.datetime(2022, 6, 27, 5, 35, 9, tzinfo=datetime.timezone.utc)],
#  ['NirmanConstruc4',
#   '@AmitTom41697283 @aajtak @anjanaomkashyap Niche tune likha hai ki amerika gav gav jate the..... woh na karana pade… https://t.co/GnkfPOZxCW',
#   1,
#   datetime.datetime(2022, 6, 27, 5, 27, 1, tzinfo=datetime.timezone.utc)],
#  ['LLUB1039',
#   '@Law1Leo Agneepath scheme laani chahiye China ko bhi',
#   37,
#   datetime.datetime(2022, 6, 27, 5, 26, 43, tzinfo=datetime.timezone.utc)],
#  ['NykAzamgarh',
#   'अग्निवीर वायु......\nआपके सपनों को देगा एक नई उड़ान।\n#agnipathyojna #Agneepath \n#Agniveer #AgniveerScheme… https://t.co/LmaA0UP1i2',
#   343,
#   datetime.datetime(2022, 6, 27, 5, 23, 32, tzinfo=datetime.timezone.utc)],
#  ['TotaltvH',
#   'अग्निपथ योजना के विरोध में हरियाणा में कांग्रेस का सत्\u200dयाग्रह #totaltv \n\nhttps://t.co/WsaAsuiO9H',
#   1963,
#   datetime.datetime(2022, 6, 27, 5, 19, 59, tzinfo=datetime.timezone.utc)],
#  ['ashishvyas_',
#   '#राजस्थान ः अग्निपथ के खिलाफ राजस्थान कांग्रेस का भी हल्ला बोल आज विधानसभा क्षेत्रों में दिए जाएंगे धरने और किया जाएगा प्रदर्शन..\n#Agneepath',
#   2978,
#   datetime.datetime(2022, 6, 27, 5, 14, 31, tzinfo=datetime.timezone.utc)],
#  ['aaliayub9',
#   'अग्निपथ पर चल, \nपायेगा तू अपनी मंजिल। \nबन के अग्निवीर,\nकर नया मुकाम हासिल।\n\n#MondayMotivation\n#BharatKeAgniveer… https://t.co/e7lqCRgQEh',
#   1215,
#   datetime.datetime(2022, 6, 27, 5, 11, 44, tzinfo=datetime.timezone.utc)],
#  ['IYC_UPEast',
#   '"अग्निपथ" योजना देश के युवाओं के लिए विश्वासघात है।\n\n#AgnipathScheme #Agneepath https://t.co/ebnz1WDYt8',
#   53044,
#   datetime.datetime(2022, 6, 27, 5, 8, 51, tzinfo=datetime.timezone.utc)],
#  ['AnnuMal25339252',
#   '@NewsroomPostCom Agneepath Ke samarthak Hain',
#   2,
#   datetime.datetime(2022, 6, 27, 5, 4, 19, tzinfo=datetime.timezone.utc)],
#  ['punjabkesari',
#   'Agneepath scheme: वायुसेना में भर्ती के लिए 3 दिन में 56,960 रजिस्ट्रेशन...5 जुलाई को बंद होगा पंजीकरण… https://t.co/MVa4VV7U0z',
#   214371,
#   datetime.datetime(2022, 6, 27, 5, 4, 9, tzinfo=datetime.timezone.utc)],
#  ['rpbreakingnews',
#   'अग्निपथ योजना के विरोध में आज कांग्रेस का प्रदेश भर में हल्ला बोल, 200 विधानसभा क्षेत्रों में होगा प्रदर्शन https://t.co/ojZizWvdTk',
#   847983,
#   datetime.datetime(2022, 6, 27, 5, 3, 6, tzinfo=datetime.timezone.utc)],
#  ['Expressnewsbha',
#   'अग्निपथ भर्ती योजना को लेकर सत्यपाल मलिक की मोदी सरकार को सलाह,\n वापस लो अग्निपथ स्कीम, नहीं तो शादी को भी…… \nhttps://t.co/eu9s4ebugb',
#   1735,
#   datetime.datetime(2022, 6, 27, 5, 1, 40, tzinfo=datetime.timezone.utc)],
#  ['prabhatkhabar',
#   'Agneepath Scheme: अग्निपथ योजना के तहत वायुसेना को 56 हजार से अधिक मिले आवेदन, जानिए क्या है अंतिम तिथि… https://t.co/RIR0XGKvIj',
#   213335,
#   datetime.datetime(2022, 6, 27, 4, 44, 23, tzinfo=datetime.timezone.utc)],
#  ['rockybh80207093',
#   '@rohanrgupta Agneepath galat hai',
#   0,
#   datetime.datetime(2022, 6, 27, 4, 44, 22, tzinfo=datetime.timezone.utc)],
#  ['LaxmikantVyas',
#   'केंद्र सरकार की अग्निपथ योजना का मुस्लिम समाज ने खुलकर किया स्वागत, सुन्नी उलेमा काउंसिल ने युवाओं से की अपील… https://t.co/AfXjTUWOEE',
#   69,
#   datetime.datetime(2022, 6, 27, 4, 35, 38, tzinfo=datetime.timezone.utc)],
#  ['PSacadeva',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n\n#AgnipathScheme https://t.co/jMl3RxeSEW https://t.co/wiqYpHoVop',
#   26,
#   datetime.datetime(2022, 6, 27, 4, 34, 7, tzinfo=datetime.timezone.utc)],
#  ['humsamvet',
#   'रिटायरमेंट के बाद शादी को तरसेंगे अग्निवीर, अग्निपथ योजना युवाओं को बर्बाद कर देगी: सत्यपाल मलिक। पढ़िए पूरी ख़बर… https://t.co/jHB6yIw0F4',
#   677,
#   datetime.datetime(2022, 6, 27, 4, 33, 57, tzinfo=datetime.timezone.utc)],
#  ['Sanjeev80389106',
#   '@rajnathsingh Aur jo Agneepath Seema ke tahat aapane 4 Sal Ka Kiya Hai usmein 25 percent lene hain usko 50% kar diy… https://t.co/5gCVmIRo4V',
#   0,
#   datetime.datetime(2022, 6, 27, 4, 24, 17, tzinfo=datetime.timezone.utc)],
#  ['A1TVNEWS',
#   'नहीं थम रहा Agneepath Scheme का विवाद, राजस्थान में Congress और रालोपा का हल्ला बोल\n@GovindDotasra @RahulGandhi… https://t.co/03WFDJRD9j',
#   6399,
#   datetime.datetime(2022, 6, 27, 4, 23, 25, tzinfo=datetime.timezone.utc)],
#  ['Arjunpchaudhary',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n\n#AgnipathScheme \n@IAF_MCC https://t.co/vSN5aAfol7',
#   3129,
#   datetime.datetime(2022, 6, 27, 4, 22, 39, tzinfo=datetime.timezone.utc)],
#  ['DanishSaifi_ji',
#   '@NasirHussainINC @INCIndia @INCKarnataka Agneepath Yojana Wapas Lo Wapas lo Wapas Lo Wapas Agar Himmat Hai To Mantri ji bhejen Apne beton Ko',
#   83,
#   datetime.datetime(2022, 6, 27, 4, 22, 23, tzinfo=datetime.timezone.utc)],
#  ['DanishSaifi_ji',
#   '@AkhileshPSingh Agneepath Yojana Wapas Lo Wapas lo Agar Himmat Hai To BJP Walon bhejo Apne bete ko',
#   83,
#   datetime.datetime(2022, 6, 27, 4, 16, 18, tzinfo=datetime.timezone.utc)],
#  ['rk2002verma',
#   'लग गयी आग मेरे घर में बचा ही क्या हैं, और बच गया में समझ लो जला ही क्या हैं । #AgnipathScheme… https://t.co/6STiLxX4Q8',
#   43,
#   datetime.datetime(2022, 6, 27, 4, 13, 38, tzinfo=datetime.timezone.utc)],
#  ['DrArchnaThakur1',
#   'कहते हैं जोश के साथ होश बहुत ज़रूरी हैं \nजोश वहाँ दिखाना चाहिए जहां देश के ऊपर संकट हो ना की देश को संकट में डालने… https://t.co/1qCwploGhp',
#   5382,
#   datetime.datetime(2022, 6, 27, 3, 59, 5, tzinfo=datetime.timezone.utc)],
#  ['manishbpl1',
#   'अगर राष्ट्ररक्षकों की #पेंशन सरकार खत्म कर रही है तो फिर इस सेवा का मौका सभी सम्मानित #जनप्रतिनिधियों को भी मिलना… https://t.co/6cwhs2YDi0',
#   4505,
#   datetime.datetime(2022, 6, 27, 3, 58, 4, tzinfo=datetime.timezone.utc)],
#  ['ScorpionHere',
#   '3 हजार अग्निवीर स्लॉट्स के लिए 60 हजार आवेदन आ चुके। अभी और आयेंगे। यही असल युवा जनता है। ट्रेन फूंकने वाले तो दंगा… https://t.co/VguJ7EPUvU',
#   370,
#   datetime.datetime(2022, 6, 27, 3, 55, 45, tzinfo=datetime.timezone.utc)],
#  ['jantaserishta',
#   'छत्तीसगढ़ में कांग्रेस का सत्याग्रह आज, अग्निपथ स्कीम का करेंगे विरोध https://t.co/HAjkWp8mNV',
#   13828,
#   datetime.datetime(2022, 6, 27, 3, 50, 37, tzinfo=datetime.timezone.utc)],
#  ['IBC24News',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n\n#AgnipathScheme | #Agnipath https://t.co/2JysrHbb99',
#   119819,
#   datetime.datetime(2022, 6, 27, 3, 50, 7, tzinfo=datetime.timezone.utc)],
#  ['Neo_NeoNews',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n\n#AgnipathScheme https://t.co/OLP37R4JcO',
#   1239,
#   datetime.datetime(2022, 6, 27, 3, 47, 29, tzinfo=datetime.timezone.utc)],
#  ['PSacadeva',
#   '@Shadab65272858 @news24tvchannel Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया… https://t.co/NbhmhfFJ0F',
#   26,
#   datetime.datetime(2022, 6, 27, 3, 47, 10, tzinfo=datetime.timezone.utc)],
#  ['PSacadeva',
#   '@news24tvchannel Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \nयह तो आपके ही समाचार/… https://t.co/mHutn0qw0z',
#   26,
#   datetime.datetime(2022, 6, 27, 3, 46, 14, tzinfo=datetime.timezone.utc)],
#  ['rpbreakingnews',
#   'अग्निपथ योजना का  विरोध , टोंक में कांग्रेस का सत्याग्रह आज, सचिन पायलट होंगे शामिल https://t.co/yKmBYUTgyq',
#   847983,
#   datetime.datetime(2022, 6, 27, 3, 45, 19, tzinfo=datetime.timezone.utc)],
#  ['INews64',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n\n#AgnipathScheme https://t.co/nqpZO1NPA6',
#   115,
#   datetime.datetime(2022, 6, 27, 3, 43, 27, tzinfo=datetime.timezone.utc)],
#  ['firstbiharnews',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n\n#AgnipathScheme https://t.co/90tJ643YBh',
#   82795,
#   datetime.datetime(2022, 6, 27, 3, 41, 52, tzinfo=datetime.timezone.utc)],
#  ['Yadav_Rajja',
#   '@suryapsingh_IAS Agneepath aese  log bhi avedan kar rhe hae jinko army me koi interest nhi tha . Na hi hae . Unka 11 lakh dikh rhe hae.',
#   1488,
#   datetime.datetime(2022, 6, 27, 3, 30, 28, tzinfo=datetime.timezone.utc)],
#  ['ArvindSSisodia',
#   'Agneepathभारत और भारतीय संस्कृति की रक्षार्थ " अग्निपथ " योजना अमृत के समान - अरविन्द सिसौदिया \nhttps://t.co/Bdf9Pv14lc',
#   592,
#   datetime.datetime(2022, 6, 27, 3, 25, 50, tzinfo=datetime.timezone.utc)],
#  ['news24tvchannel',
#   'Agneepath Scheme:वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन किया \n\n#AgnipathScheme https://t.co/8Z7S1r38JO',
#   953934,
#   datetime.datetime(2022, 6, 27, 3, 20, 38, tzinfo=datetime.timezone.utc)],
#  ['Narendr26388381',
#   'केंद्र सरकार की अग्निपथ योजना का मुस्लिम समाज ने खुलकर किया स्वागत, सुन्नी उलेमा काउंसिल ने युवाओं से की अपील… https://t.co/vCQ2VBPQWr',
#   85,
#   datetime.datetime(2022, 6, 27, 3, 19, 55, tzinfo=datetime.timezone.utc)],
#  ['ZeeBiharNews',
#   'अग्निपथ योजना को लेकर कन्हैया कुमार ने बोला सरकार पर हमला, कहा-युवाओं के भविष्य से हो रहा है खिलवाड़\n\nhttps://t.co/uBTquhHrLb',
#   773437,
#   datetime.datetime(2022, 6, 27, 3, 17, 35, tzinfo=datetime.timezone.utc)],
#  ['modhvadiya_k',
#   'केंद्र सरकार की अग्निपथ योजना का मुस्लिम समाज ने खुलकर किया स्वागत, सुन्नी उलेमा काउंसिल ने युवाओं से की अपील… https://t.co/lZgQUTsZXN',
#   4209,
#   datetime.datetime(2022, 6, 27, 3, 17, 19, tzinfo=datetime.timezone.utc)],
#  ['AmarUjalaNews',
#   "Agnipath Scheme: 'शादी को भी तरसेंगे अग्निवीर, अग्निपथ योजना युवाओं को कर देगी बर्बाद', बोले राज्यपाल सत्यपाल मलिक… https://t.co/DhTpuewHGJ",
#   1974726,
#   datetime.datetime(2022, 6, 27, 3, 7, 58, tzinfo=datetime.timezone.utc)],
#  ['JaiBhagwanTyag1',
#   'Agneepath Scheme: अग्निवीर योजना के विरोधियों को पड़ा तमाचा, वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन कर… https://t.co/5Bc4CM7hFV',
#   1954,
#   datetime.datetime(2022, 6, 27, 3, 5, 39, tzinfo=datetime.timezone.utc)],
#  ['_MadhureshSingh',
#   'केंद्र सरकार की अग्निपथ योजना का मुस्लिम समाज ने खुलकर किया स्वागत, सुन्नी उलेमा काउंसिल ने युवाओं से की अपील… https://t.co/dgYaIyrkkO',
#   73,
#   datetime.datetime(2022, 6, 27, 3, 5, 1, tzinfo=datetime.timezone.utc)],
#  ['SultanA18854432',
#   'रामचंद्र कह गए सिया से \nऐसा कलयुग आएगा बाप करता \nरहेगा नौकरी बेटा रिटायर  हो जाएगा\n#Agneepath #अग्निवीर',
#   528,
#   datetime.datetime(2022, 6, 27, 2, 52, 58, tzinfo=datetime.timezone.utc)],
#  ['AmitKum30345523',
#   'सुप्रभात \n #सक्षमता के साथ दृढ़  इच्छा शक्ति  होना आवश्यक  होता है ।\n#Agneepath \n#AgnipathRecruitmentScheme… https://t.co/vbvCX1UcJf',
#   120,
#   datetime.datetime(2022, 6, 27, 2, 50, 29, tzinfo=datetime.timezone.utc)],
#  ['NewsroomPostCom',
#   'Agneepath Scheme: अग्निवीर योजना के विरोधियों को पड़ा तमाचा, वायुसेना में ही महज 3 दिन में 56000 युवाओं ने आवेदन कर… https://t.co/eFZHjA0NSs',
#   64235,
#   datetime.datetime(2022, 6, 27, 2, 48, 52, tzinfo=datetime.timezone.utc)],
#  ['Amit95730157',
#   '@Jairam_Ramesh UP ke results Agneepath ke baad hi aaye hain saahab.',
#   907,
#   datetime.datetime(2022, 6, 27, 2, 43, 53, tzinfo=datetime.timezone.utc)],
#  ['LalanKumarINC',
#   '"अग्निपथ" योजना देश के युवाओं के लिए विश्वासघात है।\n\n#AgnipathScheme #Agneepath',
#   6301,
#   datetime.datetime(2022, 6, 27, 2, 38, 11, tzinfo=datetime.timezone.utc)],
#  ['AshishY28007623',
#   '@yadavakhilesh BJP Desh Mein foot dalne ka kam kar rahi hai Agneepath Yojana ki vajah se dar is baat kahe ki Kahin… https://t.co/yuhvEFFdhU',
#   2,
#   datetime.datetime(2022, 6, 27, 2, 34, 33, tzinfo=datetime.timezone.utc)],
#  ['OmSharma_Bharat',
#   'केंद्र सरकार की अग्निपथ योजना का मुस्लिम समाज ने खुलकर किया स्वागत, सुन्नी उलेमा काउंसिल ने युवाओं से की अपील… https://t.co/q9rFzRNuII',
#   496,
#   datetime.datetime(2022, 6, 27, 2, 33, 56, tzinfo=datetime.timezone.utc)],
#  ['RavisinghRGS',
#   'कुछ सवाल-\n1)- किनको स्थाई किया जाएगा??किस प्रकार से किया जाएगा।\n2)-रिटायर होने के बाद स्टेशन पर स्टाल आवंटित करेंगे… https://t.co/oWyrNRv4ws',
#   439,
#   datetime.datetime(2022, 6, 27, 1, 56, 47, tzinfo=datetime.timezone.utc)],
#  ['AmarUjalaNews',
#   'वायु सेना : अग्निपथ योजना के 3000 पदों के लिए तीन दिन में मिले 56960 आवेदन, पांच जुलाई को बंद हो जाएगा पंजीकरण… https://t.co/Q2502Hx6Zh',
#   1974726,
#   datetime.datetime(2022, 6, 26, 23, 30, tzinfo=datetime.timezone.utc)],
#  ['vartamanbharat',
#   'अग्निपथ शहीद जनरल बिपिन रावत के विचारों और याद का अपमान है – अजय\xa0माकन https://t.co/hRZNmxDKCn',
#   51,
#   datetime.datetime(2022, 6, 26, 22, 10, 19, tzinfo=datetime.timezone.utc)],
#  ['vartamanbharat',
#   'अग्निपथ योजना जवानों के खिलाफ, उनकी उम्मीदों के साथ धोखा-सत्यपाल\xa0मलिक https://t.co/JBJKlgxhdh',
#   51,
#   datetime.datetime(2022, 6, 26, 21, 32, 27, tzinfo=datetime.timezone.utc)],
#  ['krishankantcho1',
#   'बड़ी अच्छी पहल की है सुन्नी उलेमा काउंसिल ने !\nकाबिले तारीफ है ! देश है तो हम हैं !\nजय हिंद वंदे मातरम् वंदे मातरम्… https://t.co/p04OnnQ6Jr',
#   140,
#   datetime.datetime(2022, 6, 26, 19, 46, 57, tzinfo=datetime.timezone.utc)],
#  ['AyubAli_IND',
#   'देश के नौजवानों अभी तो अग्निवीर ही आया है। आगे देखो क्या-क्या होता है। #Agniveer #Agneepath… https://t.co/8fsZngkNP2',
#   178,
#   datetime.datetime(2022, 6, 26, 18, 57, 38, tzinfo=datetime.timezone.utc)],
#  ['DivyaHimachal',
#   'अग्निपथ योजना पर युवाओं का प्रदर्शन - https://t.co/3Wn80OrYth https://t.co/1tfzAQGGLe',
#   12485,
#   datetime.datetime(2022, 6, 26, 18, 51, tzinfo=datetime.timezone.utc)],
#  ['MANOJKU31611513',
#   '@rajnathsingh @narendramodi @myogiadityanath Yeh Jeet Mubarak lakin yuvao ke liy 4 year agneepath yojna netao ke li… https://t.co/6PXDq1FqCc',
#   14,
#   datetime.datetime(2022, 6, 26, 18, 49, 28, tzinfo=datetime.timezone.utc)],
#  ['DivyaHimachal',
#   'Pratibha Singh : कांग्रेस प्रदेशाध्यक्ष प्रतिभा सिंह बोलीं, अग्निपथ स्कीम खारिज करे सरकार - https://t.co/2nCapxbgSN https://t.co/KjX8rxN6Ay',
#   12485,
#   datetime.datetime(2022, 6, 26, 18, 39, 31, tzinfo=datetime.timezone.utc)],
#  ['bibhukalyancrr1',
#   '@BeejalBhatt @SrBachchan Sholay, Deewaar, Don, Muqaddar ka Sikandar,Naseeb, Lawaaris, Satte PE Satta, Shakti, Shaan, Agneepath',
#   2,
#   datetime.datetime(2022, 6, 26, 18, 34, 53, tzinfo=datetime.timezone.utc)],
#  ['BhagwaBalak',
#   'केंद्र सरकार की अग्निपथ योजना का मुस्लिम समाज ने खुलकर किया स्वागत, सुन्नी उलेमा काउंसिल ने युवाओं से की अपील… https://t.co/L8pnPPLRuj',
#   17379,
#   datetime.datetime(2022, 6, 26, 18, 29, 21, tzinfo=datetime.timezone.utc)],
#  ['zeesalaamtweet',
#   "गवर्नर ने 'अग्निपथ’ योजना का किया विरोध; कहा-3 साल बाद युवाओं का नहीं होगा ब्याह\n#SatyapalMalik \nhttps://t.co/q9oB4lALFL",
#   13025,
#   datetime.datetime(2022, 6, 26, 18, 24, tzinfo=datetime.timezone.utc)],
#  ['DevarshiJoshi17',
#   'केंद्र सरकार की अग्निपथ योजना का मुस्लिम समाज ने खुलकर किया स्वागत, सुन्नी उलमा काउंसिल ने युवाओं से की अपील \n https://t.co/E1JUB4Ha8D',
#   1389,
# ...
#  ['Muhamma65048310',
#   '@Aftabnuh @BhupinderShooda @MehtabNuh @RahulGandhi @priyankagandhi @INCIndia @INCHaryana @DeependerSHooda… https://t.co/uElNVmFsZN',
#   666,
#   datetime.datetime(2022, 6, 25, 12, 14, 49, tzinfo=datetime.timezone.utc)],
#  ['PunjabKesariCom',
#   'अग्निपथ :   कोचिंग संचालक ने भड़काई थी सिकंदराबाद  में हिंसा, पुलिस ने किया खुलासा… https://t.co/ZKCyYXYUyl',
#   6222,
#   datetime.datetime(2022, 6, 25, 12, 14, 18, tzinfo=datetime.timezone.utc)],
#  ['zeesalaamtweet',
#   '#agneepath scheme: अग्निपथ योजना को लेकर सरकार और विपक्ष आमने-सामने\n\nhttps://t.co/eFWTsaEuiK',
#   13025,
#   datetime.datetime(2022, 6, 25, 11, 49, 53, tzinfo=datetime.timezone.utc)],
#  ['Punjabenewscha1',
#   'Agneepath Scheme की नियमित समीक्षा कर खामियों को किया जाएगा दूर: राजनाथ सिंह \n\nhttps://t.co/Mtqh1FOpmV… https://t.co/z3dPcAa0a3',
#   36,
#   datetime.datetime(2022, 6, 25, 11, 22, 40, tzinfo=datetime.timezone.utc)],
#  ['newsclickin',
#   'अग्निपथ योजना के विरोध में युवाओं के साथ में किसानों और मज़दूर भी सड़कों पर उतरे https://t.co/VpITZaVFIg',
#   57740,
#   datetime.datetime(2022, 6, 25, 11, 20, 25, tzinfo=datetime.timezone.utc)],
#  ['DanishSaifi_ji',
#   '@LambaAlka Agneepath Yojana wapas Lo wapas lo',
#   83,
#   datetime.datetime(2022, 6, 25, 11, 16, 58, tzinfo=datetime.timezone.utc)],
#  ['SACHKAHOON',
#   'अग्निपथ योजना की नियमित समीक्षा कर खामियों को दूर किया जाएगा: राजनाथ https://t.co/aOB7XjyMxF',
#   39146,
#   datetime.datetime(2022, 6, 25, 11, 3, 16, tzinfo=datetime.timezone.utc)],
#  ['Aaj_samaaj',
#   'Rewari News : अग्निपथ योजना से आधी रह जाएगी सेना में जवानों की संख्या: योगेंद्र यादव ।\n\n#haryana #Agneepathscheme… https://t.co/zcOOjfmOTR',
#   185,
#   datetime.datetime(2022, 6, 25, 10, 43, 12, tzinfo=datetime.timezone.utc)],
#  ['jantatv_news',
#   "'अग्निपथ योजना' के विरोध में 27 जून को कांग्रेस का धरना प्रदर्शन, हुड्डा बोले-योजना किसी के हित नहीं… https://t.co/59MbwuXmFc",
#   3477,
#   datetime.datetime(2022, 6, 25, 10, 40, 37, tzinfo=datetime.timezone.utc)],
#  ['vivekku79289132',
#   'Agneepath Scheme के खिलाफ आए खाप पंचायत, हरियाणा में बहिष्कार का बना रहे... https://t.co/XSZ4Tx3hYK via @YouTube',
#   1,
#   datetime.datetime(2022, 6, 25, 10, 40, 31, tzinfo=datetime.timezone.utc)],
#  ['sinam1235',
#   '@Saim19412832 @a41200376 @ABHI2747541 @CricWick @babarazam258 @imVkohli Any proof kid kuch bhi aur jo agneepath joi… https://t.co/Fzs7P7GRqs',
#   4,
#   datetime.datetime(2022, 6, 25, 10, 39, 57, tzinfo=datetime.timezone.utc)],
#  ['BedhadkKhabar',
#   'भाजपा युवाओं की हितेषी नहीं अग्नीपथ योजना से अब युवाओं को छल रहे\n\n#Agneepath  #Agniveer  #BJP4IND\n\nhttps://t.co/yrwvpBUYjf',
#   113,
#   datetime.datetime(2022, 6, 25, 10, 32, 29, tzinfo=datetime.timezone.utc)],
#  ['NewsPluse21',
#   'सीएम @bhupeshbaghel  केंद्र सरकार पर साधा निशाना, कर्मचारियों की पेंशन और #अग्निपथ_योजना  को लेकर कही ये बड़ी बात…… https://t.co/cW8CtfK26n',
#   182,
#   datetime.datetime(2022, 6, 25, 10, 27, 20, tzinfo=datetime.timezone.utc)],
#  ['newsclickin',
#   'अग्निपथ की वजह से सेना की तैयारी करने वाले लाखों नौजवान मानसिक तनाव मेंः YHB https://t.co/47i2vHbGtP',
#   57740,
#   datetime.datetime(2022, 6, 25, 10, 6, 11, tzinfo=datetime.timezone.utc)],
#  ['Shubham23754914',
#   '@rajnathsingh Kyu fadu bna rakha hai thamne balka ka  roj k tham naye topic leke aajao ho sidhi sidhi baat hai Agneepath n wapis lelo',
#   0,
#   datetime.datetime(2022, 6, 25, 10, 5, 47, tzinfo=datetime.timezone.utc)],
#  ['top10newsRJ',
#   'Agneepath Scheme Protest : अग्निपथ के विरोध में रालोपा सांसद बेनीवाल ने झोंकी ताकत @hanumanbeniwal https://t.co/muU6PYVOb0',
#   3229,
#   datetime.datetime(2022, 6, 25, 9, 32, 40, tzinfo=datetime.timezone.utc)],
#  ['cg_wall',
#   'CM भूपेश ने कर्मचारियों की पेंशन को लेकर भाजपा पर किया तीखा हमला - https://t.co/1LeGnKSyaX',
#   1699,
#   datetime.datetime(2022, 6, 25, 9, 30, 26, tzinfo=datetime.timezone.utc)],
#  ['ZeeBiharNews',
#   'Muzaffarpur: अग्निपथ योजना के विरोध में युवाओं को भड़काने वाले कोचिंग संचालकों पर नकेल कसने की तैयारी शुरु… https://t.co/9QMWj1I7Nz',
#   773439,
#   datetime.datetime(2022, 6, 25, 9, 23, 13, tzinfo=datetime.timezone.utc)],
#  ['SaranNewz',
#   '"मुझे आर्मी की वर्दी से प्यार...भर्ती चाहे 4 दिन मिले या चार साल"\n\n\'अग्निवीर योजना\' पर बोले वायरल वीडियो में दौड़ ल… https://t.co/lA5XLRfxzA',
#   298,
#   datetime.datetime(2022, 6, 25, 9, 22, 7, tzinfo=datetime.timezone.utc)],
#  ['janbhawana',
#   'अग्निपथ स्कीम: गुरुग्राम में हटाई गई धारा 144\n#AgnipathProtests #Agniveers #AgniveerRecruitmentScheme  #gurugram… https://t.co/nYEFmLVZFS',
#   1225,
#   datetime.datetime(2022, 6, 25, 9, 12, 39, tzinfo=datetime.timezone.utc)],
#  ['coolharshiv',
#   '@RahulGandhi Are tu Abhi bhi Agnipath per hi atka hua hai. Maharastra me sarkar gir rahi hai use bacha ni jagah Agn… https://t.co/v85pCF9FIk',
#   218,
#   datetime.datetime(2022, 6, 25, 9, 8, 2, tzinfo=datetime.timezone.utc)],
#  ['rohit6064',
#   '@Film4 Amitabh Bachchan Starrer : Deewar &amp; Agneepath',
#   80,
#   datetime.datetime(2022, 6, 25, 8, 54, 52, tzinfo=datetime.timezone.utc)],
#  ['tcp24News',
#   'CM बघेल ने केंद्र पर कंसा तंज, कहा- अब शादी के कार्ड पर अब "पूर्व अग्निवीर" लिखना होगा युवाओं को, रिटायरमेंट के पै… https://t.co/jDbhcniYzu',
#   381,
#   datetime.datetime(2022, 6, 25, 8, 53, 26, tzinfo=datetime.timezone.utc)],
#  ['RakeshTyagi_',
#   '*अग्निपथ योजना* \n\n*बागपत के किसानों ने कलेक्ट्रेट में किया हंगामा, एसडीएम को सौंपा ज्ञापन*\nhttps://t.co/M7WJUVkWVd',
#   3645,
#   datetime.datetime(2022, 6, 25, 8, 42, 28, tzinfo=datetime.timezone.utc)],
#  ['khabartrends',
#   'अग्निपथ योजना के समर्थन में आए युवा, बोले-चार साल क्या चार दिन के लिए भी सेना में जाने को तैयार #barabanki… https://t.co/7yEud88zCw',
#   26,
#   datetime.datetime(2022, 6, 25, 8, 29, 6, tzinfo=datetime.timezone.utc)],
#  ['navratan_daiya',
#   'देश में ऐसे ही नेताओं की जरूरत है \n#boycutagnipath \n#अग्निवीर \n#AgnipathScheme \n#Agneepath https://t.co/y4HDZLXGsq',
#   159,
#   datetime.datetime(2022, 6, 25, 8, 17, 46, tzinfo=datetime.timezone.utc)],
#  ['Darshniksamacha',
#   '"मुझे आर्मी की वर्दी से प्यार...भर्ती चाहे 4 दिन मिले या चार साल"\n\n\'अग्निवीर योजना\' पर बोले वायरल वीडियो में दौड़ ल… https://t.co/06cEP8pkbO',
#   772,
#   datetime.datetime(2022, 6, 25, 8, 8, 42, tzinfo=datetime.timezone.utc)],
#  ['cg_wall',
#   'CM Bhupesh का तंज़,युवाओ को अपने शादी कार्ड मे लिखना पड़ेगा पूर्व अग्निवीर,रिटायरमेंट मे मिलने वाले 12 लाख शादी के… https://t.co/M6CF4WABUA',
#   1699,
#   datetime.datetime(2022, 6, 25, 8, 8, 26, tzinfo=datetime.timezone.utc)],
#  ['Puneetvizh',
#   '@TweetInder @KrisNair1 @SamHarris2429 @shuchitasrivast @JoeSaldanha @Trendsetting123 @SethLalits @Ajaykumar00009… https://t.co/vUcHXFEjta',
#   5886,
#   datetime.datetime(2022, 6, 25, 8, 8, 8, tzinfo=datetime.timezone.utc)],
#  ['Puneetvizh',
#   'क्या नरेंद्र मोदी रिलायंस को ईस्ट इंडिया कंपनी बनाने के लिए ‘अग्निपथ’ पर देश को धकेल रहे हैं? https://t.co/tlW0wDIPKl',
#   5886,
#   datetime.datetime(2022, 6, 25, 8, 5, 15, tzinfo=datetime.timezone.utc)],
#  ['Naveen_MPTET',
#   '"मुझे आर्मी की वर्दी से प्यार...भर्ती चाहे 4 दिन मिले या चार साल"\n\n\'अग्निवीर योजना\' पर बोले वायरल वीडियो में दौड़ ल… https://t.co/DcISHWyRwF',
#   1885,
#   datetime.datetime(2022, 6, 25, 8, 4, 50, tzinfo=datetime.timezone.utc)],
#  ['ZeeMPCG',
#   'जीतू पटवारी ने अग्निपथ पर हिंसक प्रदर्शन को बताया देशद्रोह, कहा-माननीयों की पेंशन हो बंद\n@jitupatwari… https://t.co/9AOYkYVgZf',
#   302459,
#   datetime.datetime(2022, 6, 25, 7, 57, 45, tzinfo=datetime.timezone.utc)],
#  ['Path_finder__',
#   '#KashmiriPandits का मुद्दा दबाने के लिए #NupurSharma \n\n#NupurSharma का मुद्दा दबाने के लिए #Agneepath \n\n#Agneepath… https://t.co/QWENEF2Y1v',
#   2818,
#   datetime.datetime(2022, 6, 25, 7, 56, tzinfo=datetime.timezone.utc)],
#  ['arpitbundeli',
#   'अग्निपथ योजना पर जीतू पटवारी का बयान \nhttps://t.co/y3r4KIamIR',
#   31,
#   datetime.datetime(2022, 6, 25, 7, 51, 55, tzinfo=datetime.timezone.utc)],
#  ['ShakibA90377941',
#   'Achcha khasa Hindu Muslim chal Raha tha pata nahin kya soja  Agneepath Yojana ley aaye AB news Wale dalalon Ko sama… https://t.co/0Zcl2xVPoA',
#   4,
#   datetime.datetime(2022, 6, 25, 7, 49, 9, tzinfo=datetime.timezone.utc)],
#  ['SahneeSheshraj',
#   '@khansirpatna Sir aap agneepath scheme pe sant kyu hai ?\nYuvayo ke sath ye dokha app kaise bardaas kar sakte hai',
#   0,
#   datetime.datetime(2022, 6, 25, 7, 42, 25, tzinfo=datetime.timezone.utc)],
#  ['BiharPatrika',
#   'New post (सीएम ने अग्निपथ योजना के पुनर्विचार को लेकर पीएम मोदी से बात की या नहीं-राजद) has been published on BIHAR… https://t.co/jhj5QBV7W8',
#   435,
#   datetime.datetime(2022, 6, 25, 7, 42, 12, tzinfo=datetime.timezone.utc)],
#  ['7reTE1rw8rduH9N',
#   'https://t.co/5CVrkAbvHb यूपी में जुमे की नमाज से मौलानाओं अग्निपथ योजना का समर्थन करेंगे और एक तरफ कांग्रेस समाजवा… https://t.co/Usqeyibo4z',
#   3692,
#   datetime.datetime(2022, 6, 25, 7, 36, 11, tzinfo=datetime.timezone.utc)],
#  ['ShaitanKumar17',
#   "अग्निपथ:- प्रधानमंत्री ने कभी कोई 'परीक्षा' पास की होती तो शायद इन युवाओं का दर्द समझ पाते..\n\n#Agneepath https://t.co/wiWbpkm334",
#   226,
#   datetime.datetime(2022, 6, 25, 7, 29, 24, tzinfo=datetime.timezone.utc)],
#  ['BulletinHindi',
#   'अग्निपथ आंदोलन के दमन का हर प्रयास विफल करेंगे \n@yuvahallabol @YuvaHallaBolUP @YuvaHallaBolBR \n@AnupamConnects\n\nhttps://t.co/aIs39WDfMR',
#   150,
#   datetime.datetime(2022, 6, 25, 7, 22, 43, tzinfo=datetime.timezone.utc)],
#  ['RamSaja16349547',
#   "Agneepath Protest : 'अग्निपथ' के खिलाफ भड़की आग के पीछे कोचिंग वालों का हाथ! अलीगढ़ से 9 संचालक गिरफ्तार☝️😎",
#   175,
#   datetime.datetime(2022, 6, 25, 7, 21, 7, tzinfo=datetime.timezone.utc)],
#  ['dildar_nagar',
#   'केंद्र सरकार से अग्निपथ योजना वापस लेने की मांग - Ghazipur News https://t.co/4KdrCrseyf',
#   1219,
#   datetime.datetime(2022, 6, 25, 7, 19, 34, tzinfo=datetime.timezone.utc)],
#  ['MaharajaDigi',
#   'Agneepath Scheme - सरकार द्वारा लागू की गई अग्निपथ योजना का विरोध नहीं थ... https://t.co/qrRJIu9dXD via @YouTube',
#   203,
#   datetime.datetime(2022, 6, 25, 7, 7, 10, tzinfo=datetime.timezone.utc)],
#  ['tricitytoday',
#   'अग्निपथ योजना : बागपत के किसानों ने कलेक्ट्रेट में किया हंगामा, एसडीएम को सौंपा ज्ञापन \n#Agneepathscheme… https://t.co/xKtoNqdy4T',
#   7926,
#   datetime.datetime(2022, 6, 25, 7, 5, 53, tzinfo=datetime.timezone.utc)],
#  ['maibihar1',
#   'अग्निपथ योजना के पहले दिन देशभर से मात्र 3500 अभ्यर्थियों ने किया आवेदन https://t.co/sKjgU8Aibc',
#   20,
#   datetime.datetime(2022, 6, 25, 7, 0, 35, tzinfo=datetime.timezone.utc)],
#  ['uniquesamaynews',
#   'अब \u200bअग्निपथ स्कीम के समर्थन में आए युवा, बोले—’चार साल क्या चार दिन के लिए भी सेना में जाने को तैयार… https://t.co/fC1UEQKZFC',
#   205,
#   datetime.datetime(2022, 6, 25, 6, 57, 30, tzinfo=datetime.timezone.utc)],
#  ['indiaaheadhindi',
#   'वरिष्ठ पत्रकार @pathakalok68 के अनुसार #Agneepath स्कीम को एकसाथ लागू करना हो सकती है बहुत बड़ी गलती, बोले पहले सा… https://t.co/twPOoswicM',
#   1215,
#   datetime.datetime(2022, 6, 25, 6, 52, 26, tzinfo=datetime.timezone.utc)],
#  ['AmritVichar',
#   'https://t.co/PMHvlCA96R\n\nएटा: भारतीय किसान यूनियन ने अग्निपथ योजना के विरोध में किया प्रदर्शन, जिलाधिकारी को सौंपा ज्ञापन',
#   890,
#   datetime.datetime(2022, 6, 25, 6, 52, 6, tzinfo=datetime.timezone.utc)],
#  ['SadiaFa66216320',
#   '@yourfellowRohit @BBCHindi Agneepath scheme par kise ek muslim ne property ko kuch nhi kiya. Shantipporne tarike se… https://t.co/NmOGy6YfZ5',
#   10,
#   datetime.datetime(2022, 6, 25, 6, 48, 49, tzinfo=datetime.timezone.utc)],
#  ['mediaamalendu',
#   'किसान सभा ने अग्निपथ को कहा भाड़े के सैनिक तैयार करने की\xa0योजना https://t.co/6WPug0eYNZ',
#   4985,
#   datetime.datetime(2022, 6, 25, 6, 48, 11, tzinfo=datetime.timezone.utc)],
#  ['nedricknews',
#   '"मुझे आर्मी की वर्दी से प्यार...भर्ती चाहे 4 दिन मिले या चार साल"\nअग्निपथ योजना पर बोले रात में दौड़ लगाने वाले प्र… https://t.co/a3RHKjo4j9',
#   1078,
#   datetime.datetime(2022, 6, 25, 6, 43, 7, tzinfo=datetime.timezone.utc)],
#  ['PBusiness_1',
#   '"मुझे आर्मी की वर्दी से प्यार...भर्ती चाहे 4 दिन मिले या चार साल"\n\n\'अग्निवीर योजना\' पर बोले वायरल वीडियो में दौड़ ल… https://t.co/MvspCmwYD0',
#   18745,
#   datetime.datetime(2022, 6, 25, 6, 34, 24, tzinfo=datetime.timezone.utc)],
#  ['Jaswant12751453',
#   'Hello @rajnathsingh 21 se lekar 24 varsh walon ke liye Agneepath aur 24 se lekar 40 varsh walon ke liye kya hai',
#   25,
#   datetime.datetime(2022, 6, 25, 6, 32, 20, tzinfo=datetime.timezone.utc)],
#  ['ETVBharatBR',
#   'सदन में विपक्ष का होगा अग्निपथ पर वार? बोले BJP विधायक- भविष्य में इनके बच्चे भी इसी योजना में जाएंगे https://t.co/Ya10P5W4ef',
#   79535,
#   datetime.datetime(2022, 6, 25, 6, 31, 58, tzinfo=datetime.timezone.utc)],
#  ['RudraRajKundu',
#   'अग्निपथ योजना को वापिस लेना ही होगा, कांग्रेस ने सरकार पर बोला हमला #Agnipathskeem #CongresspartyonAgnipath\nhttps://t.co/rEE30CaZ0n',
#   2358,
#   datetime.datetime(2022, 6, 25, 6, 30, 56, tzinfo=datetime.timezone.utc)],
#  ['TheInk_News',
#   'अग्निपथ योजना को वापिस लेना ही होगा, कांग्रेस ने सरकार पर बोला हमला #Agnipathskeem #CongresspartyonAgnipath\nhttps://t.co/nucAv5z8xM',
#   1556,
#   datetime.datetime(2022, 6, 25, 6, 30, 56, tzinfo=datetime.timezone.utc)],
#  ['indianews_hr',
#   'Rohtak : अग्निपथ योजना के विरोध और बेरोजगारी के खिलाफ मोर्चा की आक्रोश रैली 25 को |\n\n#Haryana  #AgnipathProtests… https://t.co/psqqQUp3dm',
#   8869,
#   datetime.datetime(2022, 6, 25, 6, 26, 56, tzinfo=datetime.timezone.utc)],
#  ['NishpakshDastak',
#   'अग्निपथ योजना के विरोध में भारतीय किसान यूनियन ने राष्ट्रपति को भेजा ज्ञापन https://t.co/Ije1P0iiOQ via @Nishpaksh Dastak',
#   12,
#   datetime.datetime(2022, 6, 25, 6, 20, 21, tzinfo=datetime.timezone.utc)],
#  ['AnnayaTarak9',
#   'लोकतंत्र के काले अध्याय के रूप में 25 जून को हमेशा याद रखा जाएगा, 18 महीने तक मैंने इसी #Emergency में जेल काटी थी!… https://t.co/YZnxIgY6rU',
#   1972,
#   datetime.datetime(2022, 6, 25, 6, 17, 39, tzinfo=datetime.timezone.utc)],
#  ['sona_315i',
#   'लोकतंत्र के काले अध्याय के\nरूप में 25 जून को हमेशा याद रखा जाएगा, 18 महीने तक मैंने इसी #Emergency में जेल काटी थी!… https://t.co/B2zJUCvIOF',
#   263,
#   datetime.datetime(2022, 6, 25, 6, 16, 51, tzinfo=datetime.timezone.utc)],
#  ['HrithikSKP',
#   'लोकतंत्र के काले अध्याय के रूप में 25 जून को हमेशा याद रखा जाएगा, 18 महीने तक मैंने इसी #Emergency में जेल काटी थी!… https://t.co/zJAUwoJ0FX',
#   1245,
#   datetime.datetime(2022, 6, 25, 6, 16, 29, tzinfo=datetime.timezone.utc)],
#  ['Twinkle__queen',
#   'लोकतंत्र के काले अध्याय के रूप में 25 जून को हमेशा याद रखा जाएगा, 18 महीने तक मैंने इसी #Emergency में जेल काटी थी!… https://t.co/VCNF54mgs4',
#   168,
#   datetime.datetime(2022, 6, 25, 6, 16, 22, tzinfo=datetime.timezone.utc)],
#  ['salaarsagabegin',
#   'लोकतंत्र के काले अध्याय के रूप में 25 जून को हमेशा याद रखा जाएगा, 18 महीने तक मैंने इसी #Emergency में जेल काटी थी!… https://t.co/efJz7xgzds',
#   146,
#   datetime.datetime(2022, 6, 25, 6, 16, 13, tzinfo=datetime.timezone.utc)],
#  ['UnKnOwn0071407',
#   'लोकतंत्र के काले अध्याय के रूप में 25 जून को हमेशा याद रखा जाएगा, 18 महीने तक मैंने इसी #Emergency में जेल काटी थी!… https://t.co/8sWV30oyk6',
#   270,
#   datetime.datetime(2022, 6, 25, 6, 15, 46, tzinfo=datetime.timezone.utc)],
#  ['choudhari_pv',
#   'वैसे चर्चा में तो थी \nसेना,\nलेकिन निपट गई \nशिवसेना।\n\n#Agneepath \n#Shivsena',
#   126,
#   datetime.datetime(2022, 6, 25, 6, 15, 2, tzinfo=datetime.timezone.utc)],
#  ['news24tvchannel',
#   '"मुझे आर्मी की वर्दी से प्यार...भर्ती चाहे 4 दिन मिले या चार साल"\n\n\'अग्निवीर योजना\' पर बोले वायरल वीडियो में दौड़ ल… https://t.co/PVustyGr78',
#   953934,
#   datetime.datetime(2022, 6, 25, 6, 14, 8, tzinfo=datetime.timezone.utc)],
#  ['sgupta001',
#   '@Cryptic_Miind Pehle #Agneepath aayega, phir firms aayenge unko train karne ke liye. Army contract degi. Aap chronology samajhiye.',
#   165,
#   datetime.datetime(2022, 6, 25, 6, 13, 25, tzinfo=datetime.timezone.utc)],
#  ['WorldNews24x7in',
#   'बिहार विधानसभा के मानसून सत्र के पहले दिन विपक्ष ने &amp;#8216;अग्निपथ&amp;#8217; योजना का किया विरोध @WorldNews24x7in https://t.co/nH7RTAwHWx',
#   985,
#   datetime.datetime(2022, 6, 25, 6, 12, 59, tzinfo=datetime.timezone.utc)],
#  ['amitap1997',
#   '@shubhankrmishra Isme नेताजी की जगह मोदी जी कर दो और अच्छा रहेगा क्युकी यदि पेंशन बंद हो गई तो धन्याबाद तो उनका ही… https://t.co/gLHpTrtyUD',
#   199,
#   datetime.datetime(2022, 6, 25, 6, 10, 59, tzinfo=datetime.timezone.utc)]]

# %% [markdown]
# ### Making Dataframe

# %%
df = pd.DataFrame(data=twt_list, columns=['user','tweet','followers','date'])
df
# Out:
#                 user                                              tweet  \
# 0      mohiteyuvraj1  Agitation against Agneepath Yojana... #Goregao...
# 1     Thinkwithniche  आईटी क्षेत्र के इस दिग्गज का अग्निपथ योजना को ...
# 2    SANDEEPNAUTIYA8  #आंदोलनजीवी #राजा_बाबू जी कह रहे हैं कि उन 1 क...
# 3      jantaserishta  अग्निपथ स्कीम के विरोध में कांग्रेस का प्रदर्श...
# 4      PramodBJP4170  अग्निवीर को लेकर युवाओं में भारी उत्साह \n\nअब...
# ..               ...                                                ...
# 494     choudhari_pv  वैसे चर्चा में तो थी \nसेना,\nलेकिन निपट गई \n...
# 495  news24tvchannel  "मुझे आर्मी की वर्दी से प्यार...भर्ती चाहे 4 द...
# 496        sgupta001  @Cryptic_Miind Pehle #Agneepath aayega, phir f...
# 497  WorldNews24x7in  बिहार विधानसभा के मानसून सत्र के पहले दिन विपक...
# 498       amitap1997  @shubhankrmishra Isme नेताजी की जगह मोदी जी कर...
#
#      followers                      date
# 0         2026 2022-06-27 11:19:41+00:00
# 1          258 2022-06-27 11:18:32+00:00
# 2           58 2022-06-27 11:15:31+00:00
# 3        13828 2022-06-27 11:12:45+00:00
# 4         1433 2022-06-27 11:11:42+00:00
# ..         ...                       ...
# 494        126 2022-06-25 06:15:02+00:00
# 495     953934 2022-06-25 06:14:08+00:00
# 496        165 2022-06-25 06:13:25+00:00
# 497        985 2022-06-25 06:12:59+00:00
# 498        199 2022-06-25 06:10:59+00:00
#
# [499 rows x 4 columns]

# %%
# df['tweet'] = df['tweet'].astype('string')
# df['tweet']

# %% [markdown]
# ### Tokenizing words

# %%
word_tokens = word_tokenize(str(df['tweet']))
word_tokens
# Out:
# ['0',
#  'आज',
#  'का',
#  'अग्नि',
#  'वीर',
#  '\\n',
#  '#',
#  'AgnipathScheme',
#  '#',
#  'Agneepath',
#  'h',
#  '...',
#  '1',
#  '*',
#  'Agneepath',
#  'Scheme',
#  ':',
#  'वायुसेना',
#  'में',
#  'ही',
#  'महज',
#  '3',
#  'दिन',
#  'म',
#  '...',
#  '2',
#  'Mor',
#  'Mahapaur',
#  'Mor',
#  'Dwaar',
#  'का',
#  'आज',
#  'से',
#  'आगाज',
#  ',',
#  'महापौर',
#  'ए',
#  '...',
#  '3',
#  'Almora',
#  '-',
#  'अग्निपथ',
#  '(',
#  'Agneepath',
#  ')',
#  'योजना',
#  'के',
#  'विरोध',
#  'में',
#  '...',
#  '4',
#  'रायपुर',
#  'उत्तर',
#  'विधानसभा',
#  'में',
#  'सत्याग्रह',
#  'agneepath',
#  '...',
#  '...',
#  '495',
#  'नेताओं',
#  'के',
#  'पेंशन',
#  'बंद',
#  'करो।',
#  '\\n',
#  '#',
#  'Agneepath',
#  '496',
#  'सांसद',
#  'हो',
#  'तो',
#  'ऐसा~\\nवरुण',
#  'गांधी',
#  'ने',
#  'बतौर',
#  'सांसद',
#  'पें',
#  '...',
#  '497',
#  'लोकप्रिय',
#  'युवा',
#  'सांसद',
#  'वरुण',
#  'गांधी',
#  'जी',
#  'पेंशन',
#  'छोड़ने',
#  '...',
#  '498',
#  'desh',
#  'ki',
#  'soldier',
#  'hai',
#  'isliye',
#  'ShantiPunya',
#  'se',
#  'prot',
#  '...',
#  '499',
#  'AGNEEPATH',
#  'YOJANA\\n',
#  '@',
#  'narendramodi',
#  '@',
#  'AmitShah',
#  '@',
#  'myo',
#  '...',
#  'Name',
#  ':',
#  'tweet',
#  ',',
#  'Length',
#  ':',
#  '500',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# ### Loading our local hindi stopwords file

# %%
with open('./stopwords.txt', 'r', encoding='utf-8') as file:
    hindi_stopwords = file.read().replace('\n', ',')
hindi_stopwords = hindi_stopwords.split(',')
with open('./stop_hinglish.txt', 'r', encoding='utf-8') as file:
    hinglish_stopwords = file.read().replace('\n', ',')
hinglish_stopwords = hinglish_stopwords.split(',')
hindi_stopwords
# Out:
# ['मैं',
#  'मुझको',
#  'मेरा',
#  'अपने आप को',
#  'हमने',
#  'हमारा',
#  'अपना',
#  'हम',
#  'आप',
#  'आपका',
#  'तुम्हारा',
#  'अपने आप',
#  'स्वयं',
#  'वह',
#  'इसे',
#  'उसके',
#  'खुद को',
#  'कि वह',
#  'उसकी',
#  'उसका',
#  'खुद ही',
#  'यह',
#  'इसके',
#  'उन्होने',
#  'अपने',
#  'क्या',
#  'जो',
#  'किसे',
#  'किसको',
#  'कि',
#  'ये',
#  'हूँ',
#  'होता है',
#  'रहे',
#  'थी',
#  'थे',
#  'होना',
#  'गया',
#  'किया जा रहा है',
#  'किया है',
#  'है',
#  'पडा',
#  'होने',
#  'करना',
#  'करता है',
#  'किया',
#  'रही',
#  'एक',
#  'लेकिन',
#  'अगर',
#  'या',
#  'क्यूंकि',
#  'जैसा',
#  'जब तक',
#  'जबकि',
#  'की',
#  'पर',
#  'द्वारा',
#  'के लिए',
#  'साथ',
#  'के बारे में',
#  'खिलाफ',
#  'बीच',
#  'में',
#  'के माध्यम से',
#  'दौरान',
#  'से पहले',
#  'के बाद',
#  'ऊपर',
#  'नीचे',
#  'को',
#  'से',
#  'तक',
#  'से नीचे',
#  'करने में',
#  'निकल',
#  'बंद',
#  'से अधिक',
#  'तहत',
#  'दुबारा',
#  'आगे',
#  'फिर',
#  'एक बार',
#  'यहाँ',
#  'वहाँ',
#  'कब',
#  'कहाँ',
#  'क्यों',
#  'कैसे',
#  'सारे',
#  'किसी',
#  'दोनो',
#  'प्रत्येक',
#  'ज्यादा',
#  'अधिकांश',
#  'अन्य',
#  'में कुछ',
#  'ऐसा',
#  'में कोई',
#  'मात्र',
#  'खुद',
#  'समान',
#  'इसलिए',
#  'बहुत',
#  'सकता',
#  'जायेंगे',
#  'जरा',
#  'चाहिए',
#  'अभी',
#  'और',
#  'कर दिया',
#  'रखें',
#  'का',
#  'हैं',
#  'इस',
#  'होता',
#  'करने',
#  'ने',
#  'बनी',
#  'तो',
#  'ही',
#  'हो',
#  'इसका',
#  'था',
#  'हुआ',
#  'वाले',
#  'बाद',
#  'लिए',
#  'सकते',
#  'इसमें',
#  'दो',
#  'वे',
#  'करते',
#  'कहा',
#  'वर्ग',
#  'कई',
#  'करें',
#  'होती',
#  'अपनी',
#  'उनके',
#  'यदि',
#  'हुई',
#  'जा',
#  'कहते',
#  'जब',
#  'होते',
#  'कोई',
#  'हुए',
#  'व',
#  'जैसे',
#  'सभी',
#  'करता',
#  'उनकी',
#  'तरह',
#  'उस',
#  'आदि',
#  'इसकी',
#  'उनका',
#  'इसी',
#  'पे',
#  'तथा',
#  'भी',
#  'परंतु',
#  'इन',
#  'कम',
#  'दूर',
#  'पूरे',
#  'गये',
#  'तुम',
#  'मै',
#  'यहां',
#  'हुये',
#  'कभी',
#  'अथवा',
#  'गयी',
#  'प्रति',
#  'जाता',
#  'इन्हें',
#  'गई',
#  'अब',
#  'जिसमें',
#  'लिया',
#  'बड़ा',
#  'जाती',
#  'तब',
#  'उसे',
#  'जाते',
#  'लेकर',
#  'बड़े',
#  'दूसरे',
#  'जाने',
#  'बाहर',
#  'स्थान',
#  'उन्हें ',
#  'गए',
#  'ऐसे',
#  'जिससे',
#  'समय',
#  'दोनों',
#  'किए',
#  'रहती',
#  'इनके',
#  'इनका',
#  'इनकी',
#  'सकती',
#  'आज',
#  'कल',
#  'जिन्हें',
#  'जिन्हों',
#  'तिन्हें',
#  'तिन्हों',
#  'किन्हों',
#  'किन्हें',
#  'इत्यादि',
#  'इन्हों',
#  'उन्हों',
#  'बिलकुल',
#  'निहायत',
#  'इन्हीं',
#  'उन्हीं',
#  'जितना',
#  'दूसरा',
#  'कितना',
#  'साबुत',
#  'वग़ैरह',
#  'कौनसा',
#  'लिये',
#  'दिया',
#  'जिसे',
#  'तिसे',
#  'काफ़ी',
#  'पहले',
#  'बाला',
#  'मानो',
#  'अंदर',
#  'भीतर',
#  'पूरा',
#  'सारा',
#  'उनको',
#  'वहीं',
#  'जहाँ',
#  'जीधर',
#  '\ufeffके',
#  'एवं',
#  'कुछ',
#  'कुल',
#  'रहा',
#  'जिस',
#  'जिन',
#  'तिस',
#  'तिन',
#  'कौन',
#  'किस',
#  'संग',
#  'यही',
#  'बही',
#  'उसी',
#  'मगर',
#  'कर',
#  'मे',
#  'एस',
#  'उन',
#  'सो',
#  'अत',
#  '']

# %%
additional  = ['rt','rts','retweet']
# stop_words = set(stopwords.words("english"))
# NLTK stopwords + our local stopwords
swords = set().union(stopwords.words('english'),additional, hindi_stopwords,hinglish_stopwords)
len(swords)
swords
# Out:
# {'',
#  'उन्हों',
#  'खुद को',
#  'havent',
#  'clearly',
#  'jisme',
#  'didnt',
#  "we'd",
#  "that's",
#  'बही',
#  'वग़ैरह',
#  'since',
#  'say',
#  'accha',
#  'ne',
#  're',
#  'hogi',
#  'under',
#  'upon',
#  'liye',
#  'keh',
#  "they've",
#  'thus',
#  'theek',
#  'okay',
#  'dhang',
#  'mainly',
#  'seriously',
#  'anyway',
#  'abbe',
#  'anywhere',
#  'later',
#  'बहुत',
#  'saw',
#  'karne',
#  'jiski',
#  'अत',
#  'jidhar',
#  'थे',
#  'mjhe',
#  'waala',
#  'alone',
#  'raha',
#  'वे',
#  'होता है',
#  'usse',
#  'jaa',
#  'kisko',
#  "weren't",
#  'yourselves',
#  'iss',
#  'lagta',
#  'है',
#  'kinki',
#  'yes',
#  'itself',
#  'so',
#  'inward',
#  'honge',
#  'down',
#  'woh',
#  'han',
#  'than',
#  'मैं',
#  'baar',
#  'o',
#  'obviously',
#  'another',
#  'संग',
#  "let's",
#  'apan',
#  'further',
#  'this',
#  'kahte',
#  'kahan',
#  "mustn't",
#  'ones',
#  'per',
#  'weren',
#  'hain',
#  'karte',
#  'with',
#  'everywhere',
#  'someone',
#  'usi',
#  'kare',
#  'ab',
#  'saath',
#  'आज',
#  'wo',
#  'hadd',
#  'name',
#  'first',
#  'रखें',
#  'kept',
#  'bane',
#  "you've",
#  'iski',
#  'am',
#  'anyone',
#  'know',
#  'सकते',
#  'ought',
#  'tends',
#  'a',
#  'kinho',
#  'ain',
#  'हुआ',
#  'par',
#  'के बारे में',
#  'dusra',
#  'inki',
#  'लिये',
#  'if',
#  "we're",
#  'tune',
#  'rahe',
#  'main',
#  'इसलिए',
#  'निहायत',
#  'for',
#  'aap',
#  'इन्हों',
#  'don',
#  'kiya',
#  'kahaa',
#  'जिन्हों',
#  'kaun',
#  'aye',
#  'banaye',
#  'दुबारा',
#  'यही',
#  'meanwhile',
#  'retweet',
#  'banaya',
#  'might',
#  'nai',
#  'waisa',
#  'पहले',
#  'का',
#  'nevertheless',
#  "she's",
#  'regarding',
#  'sakte',
#  'inho',
#  'unki',
#  'wagaira',
#  'werent',
#  'तुम',
#  'से नीचे',
#  'vala',
#  'kitna',
#  'tried',
#  'karegi',
#  'ourselves',
#  'perhaps',
#  'jitne',
#  'hence',
#  'ऐसे',
#  'karungi',
#  'se',
#  'kahi',
#  'of',
#  'unho',
#  'hota',
#  'chal',
#  'actually',
#  'lest',
#  'thereafter',
#  "won't",
#  'गयी',
#  'अंदर',
#  'though',
#  'hona',
#  'jahaan',
#  'look',
#  'need',
#  'pe',
#  'good',
#  'neeche',
#  'said',
#  'इसकी',
#  'whole',
#  'they',
#  'should',
#  'rakhe',
#  'kinn',
#  'wala',
#  'pehle',
#  'beside',
#  'through',
#  'log',
#  'three',
#  'साबुत',
#  'everything',
#  'maybe',
#  'therefore',
#  'follows',
#  'तथा',
#  'जितना',
#  'useful',
#  'jin',
#  'kch',
#  'kull',
#  'अपना',
#  'q',
#  'however',
#  'on',
#  'would',
#  'tjhe',
#  'was',
#  'dvaara',
#  'these',
#  'teesre',
#  'near',
#  'एवं',
#  'done',
#  'के लिए',
#  'पे',
#  'rakhen',
#  'sath',
#  'uss',
#  'unse',
#  'जाती',
#  'ex',
#  'thoda',
#  'mai',
#  'नीचे',
#  'कैसे',
#  'bolo',
#  'waali',
#  'themselves',
#  'third',
#  'mana',
#  'ke',
#  'little',
#  'apna',
#  'either',
#  'कई',
#  'doing',
#  'edu',
#  'us',
#  'hamara',
#  'phli',
#  'de',
#  'wagairah',
#  'thence',
#  'but',
#  'mostly',
#  'आगे',
#  'hue',
#  'sabse',
#  'dont',
#  "where's",
#  'could',
#  'kise',
#  'yahan',
#  'ही',
#  'humein',
#  'them',
#  've',
#  'kitno',
#  "shan't",
#  'new',
#  'तरह',
#  'होता',
#  'inasmuch',
#  'को',
#  'in',
#  'बिलकुल',
#  'दूसरा',
#  'etc',
#  'itni',
#  'स्वयं',
#  'no',
#  'besides',
#  'apne',
#  'isski',
#  'करता',
#  'दो',
#  "isn't",
#  'whereupon',
#  'everyone',
#  'none',
#  'go',
#  'banao',
#  'aati',
#  'me',
#  'thoroughly',
#  'किसी',
#  'neednt',
#  'whereby',
#  'tumhara',
#  'कहाँ',
#  'were',
#  'ऊपर',
#  'sakta',
#  'two',
#  'dega',
#  'bana',
#  'इसके',
#  'karega',
#  'nowhere',
#  "i'd",
#  'see',
#  'wale',
#  "that'll",
#  'जिस',
#  'idk',
#  'shall',
#  'used',
#  'sa',
#  'उनकी',
#  'seemed',
#  'jyada',
#  'उनका',
#  'hither',
#  'इस',
#  'भी',
#  'अपने आप को',
#  'jinhe',
#  'isnt',
#  'vaale',
#  'और',
#  'sahi',
#  'throughout',
#  'hers',
#  'we',
#  'ri',
#  'सारा',
#  'kinke',
#  'aaye',
#  'que',
#  'hoyenge',
#  'ityaadi',
#  'got',
#  'uses',
#  'जरा',
#  'comes',
#  'दिया',
#  'आप',
#  'rhaa',
#  'around',
#  'cant',
#  'tak',
#  'are',
#  'best',
#  'yehi',
#  'dwara',
#  'unka',
#  'sab',
#  'होने',
#  'therein',
#  'less',
#  'happens',
#  'old',
#  'किसे',
#  'tab',
#  'our',
#  'doesnt',
#  'लिया',
#  'degi',
#  'तब',
#  'unkaa',
#  "you're",
#  'ie',
#  'kar',
#  'kis',
#  'vaali',
#  'wouldn',
#  'enough',
#  'मुझको',
#  'निकल',
#  'puri',
#  'mean',
#  'जब तक',
#  'इनकी',
#  'few',
#  'ya',
#  'what',
#  'thank',
#  'ko',
#  'vaisi',
#  'by',
#  'very',
#  'ज्यादा',
#  'yahaan',
#  'had',
#  'होते',
#  'jaise',
#  'boli',
#  'at',
#  "they'll",
#  'regards',
#  'think',
#  'unhe',
#  'well',
#  'needn',
#  'five',
#  'other',
#  'wagerah',
#  'जिन',
#  'kyun',
#  "what's",
#  'wherein',
#  'be',
#  'greetings',
#  'about',
#  'trying',
#  'phla',
#  'selves',
#  'tumhare',
#  'ussi',
#  'did',
#  'sure',
#  'sensible',
#  'says',
#  'furthermore',
#  'इसका',
#  'exactly',
#  'hm',
#  'aata',
#  'wont',
#  'going',
#  'bhi',
#  'noone',
#  'isme',
#  'k',
#  'से अधिक',
#  'herein',
#  'rts',
#  'before',
#  'थी',
#  'कुल',
#  'able',
#  'take',
#  'जायेंगे',
#  'lekin',
#  'उन्हें ',
#  'karni',
#  'nor',
#  'rakhi',
#  'denge',
#  'whereas',
#  "wasn't",
#  'which',
#  'yup',
#  'कुछ',
#  'की',
#  'bata',
#  'overall',
#  'then',
#  'जिन्हें',
#  'seems',
#  'tum',
#  'अपने',
#  'naah',
#  'karti',
#  'jiska',
#  'example',
#  'कितना',
#  'करते',
#  'inhi',
#  'any',
#  'jinn',
#  'usually',
#  'she',
#  'ja',
#  'hamare',
#  'let',
#  'yahin',
#  'followed',
#  'those',
#  'usne',
#  'jiske',
#  "mightn't",
#  'ye',
#  'ये',
#  'aaya',
#  'एक बार',
#  'mano',
#  "needn't",
#  'तिन्हों',
#  'kari',
#  'knows',
#  'bhitar',
#  'उसके',
#  'lekar',
#  'kin',
#  'तो',
#  'hamne',
#  'll',
#  'vahin',
#  'saktaa',
#  'itno',
#  'पूरा',
#  'except',
#  'un',
#  'chahiye',
#  'teri',
#  'kiske',
#  'and',
#  'dono',
#  'oh',
#  'gotten',
#  'bolta',
#  'kya',
#  'via',
#  'इन',
#  'इनके',
#  'kaisi',
#  'jisse',
#  'apart',
#  'भीतर',
#  'ma',
#  'जैसे',
#  'rather',
#  'abe',
#  'get',
#  'waisi',
#  'wahaan',
#  'chhaiye',
#  'पडा',
#  'several',
#  'jaha',
#  'rha',
#  'kiski',
#  'कोई',
#  'kahaan',
#  'whom',
#  'help',
#  'unhi',
#  'हो',
#  'तुम्हारा',
#  'as',
#  "it'd",
#  'बाहर',
#  'honaa',
#  'didn',
#  'सकती',
#  'आपका',
#  'किया',
#  "ain't",
#  'tarah',
#  'better',
#  'becoming',
#  'apnaa',
#  'banayi',
#  'looks',
#  'taken',
#  'becomes',
#  'eg',
#  'mustnt',
#  'huh',
#  'nhi',
#  'amongst',
#  'कब',
#  'vale',
#  'or',
#  'वह',
#  'hello',
#  'ek',
#  'गई',
#  'jabh',
#  'hereafter',
#  'maan',
#  'उसी',
#  'krne',
#  'maane',
#  'hereupon',
#  'far',
#  'jinki',
#  'why',
#  'come',
#  'क्यों',
#  'th',
#  'द्वारा',
#  'rakh',
#  'tho',
#  'tu',
#  'sara',
#  'bola',
#  "i'll",
#  'maani',
#  'neither',
#  'took',
#  'likely',
#  'to',
#  'whenever',
#  'bhai',
#  'aya',
#  'thodi',
#  'kaafi',
#  'karke',
#  'था',
#  'wohi',
#  'hoga',
#  'वहीं',
#  'jitna',
#  'जाने',
#  'itna',
#  'यदि',
#  'कभी',
#  'saare',
#  'करें',
#  'naa',
#  'anyhow',
#  '\ufeffके',
#  'whoever',
#  'aside',
#  'somewhere',
#  'the',
#  'aur',
#  'saara',
#  'सकता',
#  'almost',
#  'waale',
#  'never',
#  'certain',
#  'among',
#  'konsa',
#  'batao',
#  'kam',
#  'जाते',
#  'hoyengi',
#  'having',
#  'ho',
#  'tell',
#  'यहाँ',
#  'इन्हें',
#  'keeps',
#  'yah',
#  'jaisa',
#  'wahan',
#  'karenge',
#  'सो',
#  'मानो',
#  'himself',
#  'प्रति',
#  'hai',
#  'बनी',
#  'pata',
#  'kaunsa',
#  'मात्र',
#  'dusri',
#  'kisliye',
#  'whatever',
#  'aisi',
#  'whether',
#  'became',
#  'mujhe',
#  'vaisa',
#  'सारे',
#  'something',
#  'seven',
#  'upar',
#  'तक',
#  'also',
#  'six',
#  'arre',
#  'normally',
#  'four',
#  'seem',
#  't',
#  'goes',
#  'kehte',
#  'please',
#  'खुद ही',
#  'again',
#  'दूसरे',
#  'bol',
#  'kal',
#  'ka',
#  'unlikely',
#  'rakho',
#  'kafi',
#  'doesn',
#  'second',
#  'इन्हीं',
#  'cannot',
#  'kine',
#  'अब',
#  'aise',
#  'somewhat',
#  'teen',
#  'kinhe',
#  'अन्य',
#  'बड़े',
#  'will',
#  'ityadi',
#  "shouldn't",
#  'dungi',
#  'isse',
#  'downwards',
#  'issi',
#  'although',
#  'अपनी',
#  'insofar',
#  'खिलाफ',
#  'mere',
#  'के बाद',
#  'inkaa',
#  'gayi',
#  'तिन',
#  'जब',
#  'gaya',
#  'एक',
#  'उन',
#  "don't",
#  'rt',
#  'jayega',
#  'एस',
#  'वाले',
#  'must',
#  'jinhone',
#  'दौरान',
#  'kinko',
#  'mustn',
#  'couldnt',
#  'किन्हों',
#  'में कुछ',
#  'chalega',
#  'उन्होने',
#  'yours',
#  'क्यूंकि',
#  'last',
#  'में',
#  'really',
#  'किया जा रहा है',
#  'rakha',
#  'koi',
#  'my',
#  'कर',
#  'dude',
#  'between',
#  'uska',
#  "didn't",
#  'लेकिन',
#  'bolte',
#  'accordingly',
#  "we've",
#  'सभी',
#  'rahi',
#  'outside',
#  'jitni',
#  'या',
#  'hi',
#  'ever',
#  'karen',
#  'maano',
#  'साथ',
#  'mil',
#  'क्या',
#  'kabhi',
#  'हुये',
#  'जहाँ',
#  'dwaara',
#  'allows',
#  'से पहले',
#  'hua',
#  'si',
#  'मगर',
#  'लेकर',
#  'karna',
#  'गया',
#  'यहां',
#  'mein',
#  'कौन',
#  'arent',
#  'बंद',
#  'dede',
#  'tujhe',
#  'diyaa',
#  'hadn',
#  'moreover',
#  'thinking',
#  'wahin',
#  'thought',
#  'he',
#  'cause',
#  'pehla',
#  'diyo',
#  'once',
#  'nearly',
#  'ours',
#  'wahi',
#  'imo',
#  'अपने आप',
#  'लिए',
#  'bht',
#  'wants',
#  'meri',
#  'mat',
#  'just',
#  'huyi',
#  'appear',
#  'dijiye',
#  'hu',
#  'toh',
#  'namely',
#  "haven't",
#  'because',
#  'रहा',
#  'vaise',
#  'certainly',
#  'whence',
#  'viz',
#  'poora',
#  'जिसमें',
#  'tries',
#  'iske',
#  'uske',
#  'during',
#  'hereby',
#  "i'm",
#  'inc',
#  'koyi',
#  'rahaa',
#  'placed',
#  'kitni',
#  'कहा',
#  'kuchch',
#  'non',
#  "doesn't",
#  'thats',
#  'gets',
#  'अधिकांश',
#  'jinka',
#  'dekha',
#  'apni',
#  'aadi',
#  'काफ़ी',
#  'still',
#  'thi',
#  'bohot',
#  'परंतु',
#  'kiye',
#  'anyways',
#  'krna',
#  'liya',
#  'thanks',
#  'm',
#  'yahi',
#  'asking',
#  'किया है',
#  'tha',
#  'until',
#  'all',
#  "wouldn't",
#  'तहत',
#  'sometimes',
#  'यह',
#  'diye',
#  'way',
#  'jiss',
#  'teeno',
#  'yeh',
#  'jyaada',
#  'dusre',
#  'rhe',
#  'nothing',
#  'baad',
#  "here's",
#  'kyunki',
#  'too',
#  'while',
#  'kisi',
#  'novel',
#  'tumhari',
#  'किन्हें',
#  'against',
#  'both',
#  'came',
#  'ap',
#  'agar',
#  'magar',
#  'acha',
#  'yourself',
#  'ki',
#  'मे',
#  'bro',
#  'myself',
#  'le',
#  'banda',
#  "they're",
#  'anybody',
#  'every',
#  'ise',
#  'like',
#  'से',
#  'जाता',
#  'haven',
#  "should've",
#  'tere',
#  'that',
#  'saying',
#  'kitne',
#  'many',
#  'people',
#  'howbeit',
#  'abbey',
#  'hum',
#  'wasn',
#  'iska',
#  "we'll",
#  'theres',
#  'di',
#  'jinke',
#  'kinka',
#  'ok',
#  'mani',
#  'allow',
#  'after',
#  'व',
#  'kyuki',
#  'aapne',
#  'tera',
#  'anything',
#  'के माध्यम से',
#  'karta',
#  'regardless',
#  'gone',
#  'kul',
#  'उस',
#  'lo',
#  'jise',
#  'thorough',
#  'use',
#  'kara',
#  "couldn't",
#  'मै',
#  'jaisi',
#  'towards',
#  'd',
#  'thereby',
#  'bilkul',
#  'इत्यादि',
#  'thik',
#  'otherwise',
#  'plus',
#  'kaisa',
#  'com',
#  'हमने',
#  'have',
#  'में कोई',
#  'aren',
#  "they'd",
#  'it',
#  'इसमें',
#  'बड़ा',
#  'right',
#  'bad',
#  "aren't",
#  'your',
#  'necessary',
#  "you'd",
#  'thru',
#  'forth',
#  'phle',
#  'andar',
#  'किस',
#  'sent',
#  'kiska',
#  'bolti',
#  'eight',
#  'बाद',
#  'twice',
#  'you',
#  'inhe',
#  'kahin',
#  'ask',
#  'dunga',
#  'beyond',
#  'within',
#  'brief',
#  'thereupon',
#  'रही',
#  'umm',
#  'vahan',
#  'below',
#  'went',
#  'often',
#  'given',
#  'खुद',
#  'li',
#  'दोनों',
#  'किए',
#  'want',
#  'unless',
#  'कौनसा',
#  'hasnt',
#  'here',
#  'गये',
#  'yaha',
#  'hopefully',
#  'above',
#  'hui',
#  'yeah',
#  'lol',
#  'जा',
#  ...}

# %%
df['tweet']
# Out:
# 0      आज का अग्नि वीर \n#AgnipathScheme #Agneepath h...
# 1      *Agneepath Scheme: वायुसेना में ही महज 3 दिन म...
# 2      Mor Mahapaur Mor Dwaar का आज से आगाज, महापौर ए...
# 3      Almora - अग्निपथ(Agneepath) योजना के विरोध में...
# 4      रायपुर उत्तर विधानसभा में सत्याग्रह agneepath ...
#                              ...
# 495                नेताओं के पेंशन बंद करो। \n#Agneepath
# 496    सांसद हो तो ऐसा~\nवरुण गांधी ने बतौर सांसद पें...
# 497    लोकप्रिय युवा सांसद वरुण गांधी जी पेंशन छोड़ने...
# 498    desh ki soldier hai isliye ShantiPunya se prot...
# 499    AGNEEPATH YOJANA\n@narendramodi @AmitShah @myo...
# Name: tweet, Length: 500, dtype: object

# %%
# drop duplicate tweets
df.drop_duplicates(subset='tweet', inplace=True)

# %%
df.columns
# Out:
# Index(['user', 'tweet', 'followers', 'date'], dtype='object')

# %% [markdown]
# ### Preprocessing tweets

# %%
df['processed_tweet'] = df['tweet'].str.lower()\
                        .str.replace('(@[a-z0-9]+)\w+',' ')\
                        .str.replace('(http\S+)', ' ')\
                        .str.replace(' +',' ')\
                        .apply(lambda x:[i for i in x.split() if not i in swords])
# Out:
# C:\Users\nitin\AppData\Local\Temp/ipykernel_444/2345700266.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['processed_tweet'] = df['tweet'].str.lower()\

# %%
df['processed_tweet']
# Out:
# 0      [agitation, agneepath, yojana..., #goregaonvid...
# 1      [आईटी, क्षेत्र, के, दिग्गज, अग्निपथ, योजना, सम...
# 2      [#आंदोलनजीवी, #राजा_बाबू, जी, कह, 1, करोड़, लो...
# 3      [अग्निपथ, स्कीम, के, विरोध, कांग्रेस, प्रदर्शन...
# 4      [अग्निवीर, युवाओं, भारी, उत्साह, अबतक, 57000, ...
#                              ...
# 494    [वैसे, चर्चा, सेना,, निपट, शिवसेना।, #agneepat...
# 495    ["मुझे, आर्मी, वर्दी, प्यार...भर्ती, चाहे, 4, ...
# 496    [#agneepath, aayega,, phir, firms, aayenge, tr...
# 497    [बिहार, विधानसभा, के, मानसून, सत्र, के, दिन, व...
# 498    [नेताजी, जगह, मोदी, जी, अच्छा, रहेगा, क्युकी, ...
# Name: processed_tweet, Length: 499, dtype: object

# %% [markdown]
# ### Stemming

# %%
ps = PorterStemmer()
df['stemmed'] = df['processed_tweet'].apply(lambda x: [ps.stem(i) for i in x if i != ''])

# %%
df['stemmed']
# Out:
# 0      [agit, agneepath, yojana..., #goregaonvidhansa...
# 1      [आईटी, क्षेत्र, के, दिग्गज, अग्निपथ, योजना, सम...
# 2      [#आंदोलनजीवी, #राजा_बाबू, जी, कह, 1, करोड़, लो...
# 3      [अग्निपथ, स्कीम, के, विरोध, कांग्रेस, प्रदर्शन...
# 4      [अग्निवीर, युवाओं, भारी, उत्साह, अबतक, 57000, ...
#                              ...
# 494    [वैसे, चर्चा, सेना,, निपट, शिवसेना।, #agneepat...
# 495    ["मुझे, आर्मी, वर्दी, प्यार...भर्ती, चाहे, 4, ...
# 496    [#agneepath, aayega,, phir, firm, aayeng, trai...
# 497    [बिहार, विधानसभा, के, मानसून, सत्र, के, दिन, व...
# 498    [नेताजी, जगह, मोदी, जी, अच्छा, रहेगा, क्युकी, ...
# Name: stemmed, Length: 499, dtype: object

# %%
df
# Out:
#                 user                                              tweet  \
# 0      mohiteyuvraj1  Agitation against Agneepath Yojana... #Goregao...
# 1     Thinkwithniche  आईटी क्षेत्र के इस दिग्गज का अग्निपथ योजना को ...
# 2    SANDEEPNAUTIYA8  #आंदोलनजीवी #राजा_बाबू जी कह रहे हैं कि उन 1 क...
# 3      jantaserishta  अग्निपथ स्कीम के विरोध में कांग्रेस का प्रदर्श...
# 4      PramodBJP4170  अग्निवीर को लेकर युवाओं में भारी उत्साह \n\nअब...
# ..               ...                                                ...
# 494     choudhari_pv  वैसे चर्चा में तो थी \nसेना,\nलेकिन निपट गई \n...
# 495  news24tvchannel  "मुझे आर्मी की वर्दी से प्यार...भर्ती चाहे 4 द...
# 496        sgupta001  @Cryptic_Miind Pehle #Agneepath aayega, phir f...
# 497  WorldNews24x7in  बिहार विधानसभा के मानसून सत्र के पहले दिन विपक...
# 498       amitap1997  @shubhankrmishra Isme नेताजी की जगह मोदी जी कर...
#
#      followers                      date  \
# 0         2026 2022-06-27 11:19:41+00:00
# 1          258 2022-06-27 11:18:32+00:00
# 2           58 2022-06-27 11:15:31+00:00
# 3        13828 2022-06-27 11:12:45+00:00
# 4         1433 2022-06-27 11:11:42+00:00
# ..         ...                       ...
# 494        126 2022-06-25 06:15:02+00:00
# 495     953934 2022-06-25 06:14:08+00:00
# 496        165 2022-06-25 06:13:25+00:00
# 497        985 2022-06-25 06:12:59+00:00
# 498        199 2022-06-25 06:10:59+00:00
#
#                                        processed_tweet  \
# 0    [agitation, agneepath, yojana..., #goregaonvid...
# 1    [आईटी, क्षेत्र, के, दिग्गज, अग्निपथ, योजना, सम...
# 2    [#आंदोलनजीवी, #राजा_बाबू, जी, कह, 1, करोड़, लो...
# 3    [अग्निपथ, स्कीम, के, विरोध, कांग्रेस, प्रदर्शन...
# 4    [अग्निवीर, युवाओं, भारी, उत्साह, अबतक, 57000, ...
# ..                                                 ...
# 494  [वैसे, चर्चा, सेना,, निपट, शिवसेना।, #agneepat...
# 495  ["मुझे, आर्मी, वर्दी, प्यार...भर्ती, चाहे, 4, ...
# 496  [#agneepath, aayega,, phir, firms, aayenge, tr...
# 497  [बिहार, विधानसभा, के, मानसून, सत्र, के, दिन, व...
# 498  [नेताजी, जगह, मोदी, जी, अच्छा, रहेगा, क्युकी, ...
#
#                                                stemmed
# 0    [agit, agneepath, yojana..., #goregaonvidhansa...
# 1    [आईटी, क्षेत्र, के, दिग्गज, अग्निपथ, योजना, सम...
# 2    [#आंदोलनजीवी, #राजा_बाबू, जी, कह, 1, करोड़, लो...
# 3    [अग्निपथ, स्कीम, के, विरोध, कांग्रेस, प्रदर्शन...
# 4    [अग्निवीर, युवाओं, भारी, उत्साह, अबतक, 57000, ...
# ..                                                 ...
# 494  [वैसे, चर्चा, सेना,, निपट, शिवसेना।, #agneepat...
# 495  ["मुझे, आर्मी, वर्दी, प्यार...भर्ती, चाहे, 4, ...
# 496  [#agneepath, aayega,, phir, firm, aayeng, trai...
# 497  [बिहार, विधानसभा, के, मानसून, सत्र, के, दिन, व...
# 498  [नेताजी, जगह, मोदी, जी, अच्छा, रहेगा, क्युकी, ...
#
# [499 rows x 6 columns]

# %% [markdown]
# ### User audience category(followers count)

# %%
df['user_audience_category'] = pd.cut(df['followers'],[0,300,10000,999999999],include_lowest=True,labels=['small','medium','wide'])

# %%
df['user_audience_category']
# Out:
# 0      medium
# 1       small
# 2       small
# 3        wide
# 4      medium
#         ...
# 494     small
# 495      wide
# 496     small
# 497    medium
# 498     small
# Name: user_audience_category, Length: 499, dtype: category
# Categories (3, object): ['small' < 'medium' < 'wide']

# %% [markdown]
# ### Word cloud

# %%
import re
bigstring = re.sub('[a-z]',' ',str(df['processed_tweet']))
bigstring=df['processed_tweet'].apply(lambda x: ' '.join(x)).str.cat(sep=' ')
bigstring
# df['processed_tweet']
# Out:
# 'agitation agneepath yojana... #goregaonvidhansabha \u2066 \u2069 \u2066 \u2069 आईटी क्षेत्र के दिग्गज अग्निपथ योजना समर्थन … #आंदोलनजीवी #राजा_बाबू जी कह 1 करोड़ लोगों भावनायें नहीं देश के सिर्फ बेरोजगार हो… अग्निपथ स्कीम के विरोध कांग्रेस प्रदर्शन, अचानक ये...लोग हैरान अग्निवीर युवाओं भारी उत्साह अबतक 57000 अधिक युवाओं भरा आवेदन युवाओं अफवाहबाजी लगाया पू… #rahulgandhi प्रधानमंत्री मित्रों सरकारी संपत्तियों 50 साल के ठेके देकर \'दौलतवीर\' बना र… सिर्फ बेटियां नहीं बेटे घर छोड़ उठकर पानी ना पीने कपड़े धो लेते हैं,वह घ… mam agneepath yojana हमारे समझ सही नहीं हमारे सैनिकों एक्सपीरियंस वह… उत्तराखंड अग्निपथ भर्ती योजना के कांग्रेसियों अपनाया अनूठा तरीका #uttrakhand #congress… युवाओं सेना के हित अग्निपथ: वन्दना पोपली-best24news अग्निपथ स्कीम के विरोध सत्याग्रह आंदोलन, रायपुर कांग्रेस नेताओं सुंदरकांड पाठ अग्निपथ विरोध : कांग्रेस कहा- युवाओं के धोखा, केंद्र सरकार सद्बुद्धि देने राजधानी सुंदरकांड पा… agneepath scheme:वायुसेना महज 3 दिन 56000 युवाओं आवेदन 🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳 #agnipathscheme \'अग्निपथ योजना\' के राज्यों कांग्रेस नेता rjd कार्यकर्ताओं विरोध प्रदर्शन #agnipath #congress… अग्निपथ योजना के विरोध देशभर कांग्रेस प्रदर्शन, योजना बताया युवा हित के awaaz agneepath yojana wapas wapas wapas wapas अगिनपथ योजना: जवानों शहादत ‘मजाक’: राज्यसभा सांसद दीपेन्द्र हुड्डा- best24news जालौन : अग्निपथ योजना धरने बैठे कांग्रेसी written अग्निवीर बनने के वायुसेना मिले 56 हजार अधिक आवेदन, अग्निपथ के विरोध असर? अग्निपथ योजना के विरोध कांग्रेस सत्याग्रह : भाषण दे कन्हैया कुमार युवाओं विरोध, मुर्दाबाद...… अग्निपथ योजना के nsui हरियाणा के भिन्न-भिन्न जिलों धरना प्रदर्शन । अग्निपथ बिहार विधानसभा हंगामा, कानून मंत्री बोले- यूपी भाजपा जीत योजना के समर्थन उदाहरण mor mahapaur mor dwaar आगाज, महापौर एजाज़ ढेबर समस्या सुनने स्पेशल बस तैयार... … \'अग्निपथ\' के विरोध छत्तीसगढ़ सरकार #chhattisgarh #cmbhupeshbaghel #congress #agneepath agneepath recruitment scheme: भारी विरोध के अग्निवीरों भर्ती जोश, वायुसेना मिले 3 दिन 56,960 आवेद… अग्निपथ योजना के सैनिकों भविष्य अनिश्चित, केंद्र सेवानिवृत्ति आयु बढ़ाकर 65 वर्ष करे: बंगाल सीएम ममता… रामगढ़ कांग्रेसियों अग्निवीर योजना के विरोध रैली ज्ञापन #biharnews : अग्निपथ स्कीम के मुजफ्फरपुर jap प्रदर्शन #patnanews #agneepath #agnipathscheme agneepath bare khyal madam ji aapka देश सुरक्षा के घातक अग्निपथ योजना, दिल्ली कांग्रेस सरकार हमला राजस्थान कांग्रेस विधानसभा क्षेत्रों अग्निपथ योजना के सत्याग्रह पटना कांग्रेस के अग्निपथ सत्याग्रह कन्हैया कुमार के विरोध देशद्रोही के नारे लगे... #agnipathscheme… cm सिटी कांग्रेस अग्निपथ योजना हल्ला बोल , करनाल पहुंचे प्रदेश अध्यक्ष , कांग्रेस प्रभारी… अग्निपथ योजना: वायुसेना भर्ती के 3 दिन आए 56,960 आवेदन #agnipathscheme #agnipathprotests… अग्निपथ योजना के विरोध कांग्रेसियों बुलंद आवाज -36 विपक्षी विधायकों के हंगामे, के लंच के पास अग्नीपथ विधेयक बिहार विधानसभा हंगामा, अग्निपथ योजना वापस लेने मांग agneepath kanoon khilaf dharna pradarshan agneepath khilaf dharna pradarshan agneepath kanoon khilaf ham dharna pradarshan alam ansari अग्निपथ के कांग्रेस यूपी के जिलों सत्याग्रह, पूर्व अध्यक्ष लल्लू निकाला मार्च #agneepathscheme #agnipathprotest #haryana : अग्निपथ के विरोध हरियाणा कांग्रेस धरना- प्रदर्शन, सड़कों उतरे नेता और… ऋषिकेश : कांग्रेसी जुटे गंगा किनारे त्रिवेणी घाट पर, सत्याग्रह अग्निपथ b** desh kliye aapna khoya usko rahahe..… अग्नि वीर #agnipathscheme #agneepath *agneepath scheme: वायुसेना महज 3 दिन 56000 युवाओं आवेदन किया* mor mahapaur mor dwaar आगाज, महापौर एजाज़ ढेबर समस्या सुनने स्पेशल बस तैयार... #raipur… almora - अग्निपथ(agneepath) योजना के विरोध कांग्रेस सत्याग्रह रायपुर उत्तर विधानसभा सत्याग्रह agneepath योजना के विरोध कांग्रेसियों अग्निपथ के कलेक्ट्रेट सत्याग्रह अग्निवीर बनने के वायुसेना मिले 56 हजार अधिक आवेदन, अग्निपथ के विरोध असर?… अग्निपथ स्कीम राबड़ी देवी पीएम मोदी अलग मांग, कहा- सरकार करे काम #agnipathscheme गोहाना देश के युवाओं भविष्य बर्बाद वाली भाजपा सरकार अग्निपथ योजना के कांग्रेस सत्याग्रह… सरकार के दबाव \'अग्निपथ\' के खुलकर नहीं बोल सेनाधिकारी : परमवीर चक्र विजेता ऑनररी कैप्टन योगेन्द्र सिंह… अग्निपथ भर्ती योजना: भारतीय वायुसेना भर्ती के युवाओं क्रेज, आए इतने आवेदन बिह ...

# %%
wordcloud = WordCloud(    font_path="C:/Users/nitin/Documents/DL/Devanagari/Lohit-Devanagari.ttf",
                          stopwords="C:/Users/nitin/Documents/DL/stopwords2.txt",
                          background_color='white',
                          
                          width=400,
                          height=330
                         ).generate_from_text(bigstring)

plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(wordcloud)

# %%
# font_prop = FontProperties(fname='C:/Users/nitin/Documents/DL/Devanagari/Lohit-Devanagari.ttf', size=18)

# %%
# Adding Hindi fonts for plotting
import matplotlib
from matplotlib import font_manager

fe = font_manager.FontEntry(
    fname='C:/Users/nitin/Documents/DL/Devanagari/Lohit-Devanagari.ttf',
    name='Lohit_Devanagari'
)
font_manager.fontManager.ttflist.insert(0, fe)

# %% [markdown]
# ### Top Hashtags

# %%
hashtags = df['tweet'].apply(lambda x: pd.value_counts(re.findall('(#\w+)', x.lower() )))\
                     .sum(axis=0)\
                     .to_frame()\
                     .reset_index()\
                     .sort_values(by=0,ascending=False)
hashtags.columns = ['hashtag','occurences']

# %%
hashtags.head(10)
# Out:
#                        hashtag  occurences
# 2                   #agneepath        41.0
# 12             #agnipathscheme        36.0
# 16                   #agniveer         7.0
# 32                   #congress         7.0
# 6             #agneepathscheme         7.0
# 8                    #agnipath         7.0
# 37                  #emergency         6.0
# 78                         #अग         6.0
# 10           #agnipathprotests         6.0
# 11  #agnipathrecruitmentscheme         6.0

# %%
# plt.rcParams['font.family'] = fe.name

# %%
plt.rcParams['font.family'] = "sans-serif"

# %%
plt.figure(figsize=(14,7))
hashtags[:10].plot(kind='bar',y='occurences',x='hashtag')
plt.grid(False)
plt.suptitle('Top 10 Hashtags for keyword: AGNEEPATH', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Top 10 Hashtags for keyword: AGNEEPATH')

# %% [markdown]
# ### Top mentioned users

# %%
top_mentioned_users = df['tweet'].str\
          .findall('(@[A-Za-z0-9]+)')\
          .apply(lambda x: pd.value_counts(x))\
          .sum(axis=0)\
          .sort_values(ascending=False)[:10]
top_mentioned_users
# Out:
# @INCIndia         10.0
# @narendramodi      7.0
# @RahulGandhi       5.0
# @rajnathsingh      5.0
# @RJDforIndia       4.0
# @kanhaiyakumar     4.0
# @yadavakhilesh     4.0
# @ANI               4.0
# @YouTube           3.0
# @INCBihar          3.0
# dtype: float64

# %%
top_mentioned_users.plot(kind='bar')
plt.grid(False)
plt.suptitle('Top 10 Users for keyword: AGNEEPATH', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Top 10 Users for keyword: AGNEEPATH')

# %% [markdown]
# ### Most occuring words

# %%
words = df['processed_tweet'].dropna()\
                            .apply(lambda y: pd.value_counts(re.findall('([\s]\w+[\s])',' '.join(y))))\
                            .sum(axis=0)\
                            .to_frame()\
                            .reset_index()\
                            .sort_values(by=0,ascending=False)
words.columns = ['word','occurences']

# %%
words.head(10)
# Out:
#             word  occurences
# 39    agneepath         27.0
# 20            4         22.0
# 194      scheme         19.0
# 24        56000         17.0
# 15           25         17.0
# 262         महज         17.0
# 234          आए          9.0
# 12         2024          9.0
# 223      yojana          8.0
# 2           100          8.0

# %%
words[:10].plot(kind='bar',y='occurences',x='word')
plt.grid(False)
plt.suptitle('Top 10 Words for keyword: AGNEEPATH', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Top 10 Words for keyword: AGNEEPATH')
# c:\users\nitin\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\nitin\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\nitin\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\nitin\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\nitin\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 2310 (\N{DEVANAGARI LETTER AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\nitin\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 2319 (\N{DEVANAGARI LETTER E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Most occuring bigram words

# %%
from nltk import bigrams
bigramseries = pd.Series([word for sublist in df['processed_tweet'].dropna()\
                    .apply(lambda x: [i for i in bigrams(x)])\
                    .tolist() for word in sublist])\
                    .value_counts()
bigramseries
# Out:
# (अग्निपथ, योजना)    149
# (योजना, के)          69
# (के, विरोध)          51
# (केंद्र, सरकार)      39
# (सरकार, अग्निपथ)     37
#                    ...
# (", योजना)            1
# (योजना, अमृत)         1
# (अमृत, के)            1
# (के, -)               1
# (धन्याबाद, ही…)       1
# Length: 3260, dtype: int64

# %%
bigramseries.head(10)
# Out:
# (अग्निपथ, योजना)     149
# (योजना, के)           69
# (के, विरोध)           51
# (केंद्र, सरकार)       39
# (सरकार, अग्निपथ)      37
# (स्वागत,, सुन्नी)     27
# (खुलकर, स्वागत,)      27
# (समाज, खुलकर)         27
# (उलेमा, काउंसिल)      27
# (सुन्नी, उलेमा)       27
# dtype: int64

# %%
# Changing plot font family to hindi
matplotlib.rcParams['font.family'] = fe.name

# %%
bigramseries[:10].plot(kind='bar')
# plt.suptitle('Top 10 Bigrams for keyword: AGNEEPATH', fontsize=18)
# Out:
# <AxesSubplot:>
